# %% [markdown]
# # Model #1 Synonym & Library Extraction - Exact Match

# %%
import s3fs
import boto3
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')

import re
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/ec2-user/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Pull in Data From S3 Bucket

# %%
# csv file
#df_books_filtered = pd.read_csv('s3://ec2-jupyter-notebook-us-west-2-8c94c42abbd5478ca9a1a477613965a7/books_filtered.csv')
text_data = pd.read_csv('s3://book-data-ucb-capstone-s2022/books_filtered_colsreduced.csv')
print('Total Text DF size:', len(text_data))

model_data = pd.read_csv('s3://book-data-ucb-capstone-s2022/tokenized_data.csv')
print('Tokenized Text DF Size:', len(model_data))
# Out:
# Total Text DF size: 29652
# Tokenized Text DF Size: 29652

# %%
model_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                       bookId  \
# 0             0           0                     2767052-the-hunger-games
# 1             1           1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2             2           2                   2657.To_Kill_a_Mockingbird
# 3             3           3                     1885.Pride_and_Prejudice
# 4             4           4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# 4                            Stephenie Meyer
#
#                                          description         isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9.78044E+12
# 1  There is a door at the end of a silent corrido...  9.78044E+12
# 2  The unforgettable novel of a childhood in a sl...        1E+13
# 3  Alternate cover edition of ISBN 9780679783268S...        1E+13
# 4  About three things I was absolutely positive.\...  9.78032E+12
#
#                                               genres pages  ...  Childrens  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374  ...        NaN
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870  ...  Childrens
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...   324  ...        NaN
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...   279  ...        NaN
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501  ...        NaN
#
#   New Adult  Fantasy History  Dystopia Manga Thriller Graphic Novels  Romance  \
# 0       NaN  Fantasy     NaN  Dystopia   NaN      NaN            NaN  Romance
# 1       NaN  Fantasy     NaN       NaN   NaN      NaN            NaN      NaN
# 2       NaN      NaN     NaN       NaN   NaN      NaN            NaN      NaN
# 3       NaN      NaN     NaN       NaN   NaN      NaN            NaN  Romance
# 4       NaN  Fantasy     NaN       NaN   NaN      NaN            NaN  Romance
#
#                                               tokens
# 0  {'sentence', 'america', 'take', 'life', 'conte...
# 1  {'strength', 'lot', 'ordinary', 'end', 'things...
# 2  {'published', 'experience', 'roots', 'classicc...
# 3  {'austens', 'wit', 'cover', 'austen', 'popular...
# 4  {'positivefirst', 'himand', 'things', 'part', ...
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Preprocessing

# %%
def preprocess_text(text):

  #lowercase text
  text_preprocessed = text.lower()
  #remove punctuation
  text_preprocessed = re.sub(r'[^a-zA-Z ]+', '', text_preprocessed)
  #tokenize for stopword removal
  text_preprocessed = word_tokenize(text_preprocessed)
  #remove stopwords
  text_preprocessed = [word for word in text_preprocessed if word not in stopwords.words('english')]
  #join to make string again
  #text_preprocessed = (" ").join(text_preprocessed)

  return text_preprocessed

# %%
# %%time
model_data['tokens'] = model_data['description'].apply(lambda x: preprocess_text(x))
# Out:
# CPU times: user 5min 14s, sys: 22.9 s, total: 5min 37s
# Wall time: 5min 37s

# %%
model_data['tokens'].head()
# Out:
# 0    [winning, means, fame, fortunelosing, means, c...
# 1    [door, end, silent, corridor, haunting, harry,...
# 2    [unforgettable, novel, childhood, sleepy, sout...
# 3    [alternate, cover, edition, isbn, since, immed...
# 4    [three, things, absolutely, positivefirst, edw...
# Name: tokens, dtype: object

# %%
#save dataset to csv
model_data.to_csv('tokenized_data.csv')
#download & send to Amber

# %%
from rake_nltk import Rake
r = Rake()
keyword_col = []
for d in model_data['description']:
  my_text = d
  r.extract_keywords_from_text(my_text)
  keywordList = []
  rankedList = r.get_ranked_phrases_with_scores()
  for keyword in rankedList:
    keyword_updated = keyword[1].split()
    keyword_updated_string = " ".join(keyword_updated[:2])
    keywordList.append(keyword_updated_string)
    if(len(keywordList)>9):
      break
  keyword_col.append(set(keywordList))
model_data['RAKE'] = keyword_col

# %%
model_data.head()
# Out:
#    Unnamed: 0                                       bookId  \
# 0           0                     2767052-the-hunger-games
# 1           1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2           2                   2657.To_Kill_a_Mockingbird
# 3           3                     1885.Pride_and_Prejudice
# 4           4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# 4                            Stephenie Meyer
#
#                                          description         isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9.78044E+12
# 1  There is a door at the end of a silent corrido...  9.78044E+12
# 2  The unforgettable novel of a childhood in a sl...        1E+13
# 3  Alternate cover edition of ISBN 9780679783268S...        1E+13
# 4  About three things I was absolutely positive.\...  9.78032E+12
#
#                                               genres pages publishDate  ...  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374   9/14/2008  ...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870   9/28/2004  ...
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...   324   5/23/2006  ...
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...   279  10/10/2000  ...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501    9/6/2006  ...
#
#    Childrens New Adult  Fantasy History  Dystopia Manga Thriller  \
# 0        NaN       NaN  Fantasy     NaN  Dystopia   NaN      NaN
# 1  Childrens       NaN  Fantasy     NaN       NaN   NaN      NaN
# 2        NaN       NaN      NaN     NaN       NaN   NaN      NaN
# 3        NaN       NaN      NaN     NaN       NaN   NaN      NaN
# 4        NaN       NaN  Fantasy     NaN       NaN   NaN      NaN
#
#   Graphic Novels  Romance                                               RAKE
# 0            NaN  Romance  {old katniss, without really, shining capitol,...
# 1            NaN      NaN  {unbearable sacrifice, silent corridor, haunti...
# 2            NaN      NaN  {18 million, young alabama, winning film, slee...
# 3            NaN  Romance  {romantic clash, regency england, radiant wit,...
# 4            NaN  Romance  {deeply seductive, part might, love story, ext...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Libraries

# %%
def create_synsets(event):
  
  synonym = [] 
    
  for synset in wordnet.synsets(event): 
      for i in synset.lemmas(): 
          synonym.append(i.name()) # add all the synonyms available 
    
  return synonym

# %%
#creating library dataframe


life_events = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 
               'moving', 'coming of age', 'death']

#create synsets for select events where decent synsets exist
relationship_list = create_synsets('go_steady') + ['relationship', 'kinship']
marriage_list = create_synsets('wedding') + create_synsets('marriage')

#replace underscore (_) with space
relationship_list = [i.replace("_", " ") for i in relationship_list]
marriage_list = [i.replace("_", " ") for i in marriage_list]

synsets = [['college', 'university', 'campus', 'academia'], 
           relationship_list, 
           ['breakup', 'break up', 'split', 'split up', 'broken up', 'dumped'], 
           ['divorce', 'divorced', 'separate', 'separated'], 
           marriage_list, 
           ['move', 'moving'], 
           ['coming of age', 'growing up'], 
           ['death', 'decease', 'deceased', 'dying']]

# Create the pandas DataFrame with column name is provided explicitly
df_lib = pd.DataFrame(life_events, columns=['life_event'])
df_lib['synsets'] = synsets
 
# print dataframe.
df_lib
# Out:
#       life_event                                            synsets
# 0     university            [college, university, campus, academia]
# 1  relationships  [go steady, go out, date, see, relationship, k...
# 2      break ups  [breakup, break up, split, split up, broken up...
# 3        divorce           [divorce, divorced, separate, separated]
# 4        wedding  [wedding, wedding ceremony, nuptials, hymeneal...
# 5         moving                                     [move, moving]
# 6  coming of age                        [coming of age, growing up]
# 7          death                  [death, decease, deceased, dying]

# %% [markdown]
# ## Match Tokens to Libraries

# %%
def library_match(model_data, library_data):
  for index, row in library_data.iterrows(): #per life event
    LE = row['life_event']
    LE_words = row['synsets']
    LE_list = []
    for tokens in model_data['tokens']: #for each book 
        tokenss = set(tokens)
      #find set intersection (common words)
        matches = tokenss.intersection(LE_words)
        #matches = list(matches)
        LE_list.append(matches)
    model_data[LE] = LE_list

# %%
library_match(model_data, df_lib)

# %%
model_data
# Out:
#        Unnamed: 0.1  Unnamed: 0                                       bookId  \
# 0                 0           0                     2767052-the-hunger-games
# 1                 1           1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                 2           2                   2657.To_Kill_a_Mockingbird
# 3                 3           3                     1885.Pride_and_Prejudice
# 4                 4           4                               41865.Twilight
# ...             ...         ...                                          ...
# 29647         29647       52473                           11492014-fractured
# 29648         29648       52474                             11836711-anasazi
# 29649         29649       52475                              10815662-marked
# 29650         29650       52476                         11330278-wayward-son
# 29651         29651       52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 29647                                  Fractured             Fateful #2
# 29648                                    Anasazi      Sense of Truth #2
# 29649                                     Marked      Soul Guardians #1
# 29650                                Wayward Son                    NaN
# 29651                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  \
# 0                                        Suzanne Collins
# 1              J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                             Harper Lee
# 3              Jane Austen, Anna Quindlen (Introduction)
# 4                                        Stephenie Meyer
# ...                                                  ...
# 29647                   Cheri Schmidt (Goodreads Author)
# 29648                                      Emma Michaels
# 29649                  Kim Richardson (Goodreads Author)
# 29650  Tom Pollack (Goodreads Author), John Loftus (G...
# 29651                    Misty Moncur (Goodreads Author)
#
#                                              description         isbn  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9.78044E+12
# 1      There is a door at the end of a silent corrido...  9.78044E+12
# 2      The unforgettable novel of a childhood in a sl...        1E+13
# 3      Alternate cover edition of ISBN 9780679783268S...        1E+13
# 4      About three things I was absolutely positive.\...  9.78032E+12
# ...                                                  ...          ...
# 29647  The Fateful Trilogy continues with Fractured. ...  2.94001E+12
# 29648  'Anasazi', sequel to 'The Thirteenth Chime' by...        1E+13
# 29649  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  9.78146E+12
# 29650  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  9.78145E+12
# 29651  Fighting in Helaman's army is Keturah's deepes...   9.7816E+12
#
#                                                   genres pages  ...  Romance  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374  ...  Romance
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870  ...      NaN
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...   324  ...      NaN
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...   279  ...  Romance
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501  ...  Romance
# ...                                                  ...   ...  ...      ...
# 29647  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...     0  ...  Romance
# 29648                         ['Mystery', 'Young Adult']   190  ...      NaN
# 29649  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280  ...  Romance
# 29650  ['Fiction', 'Mystery', 'Historical Fiction', '...   507  ...      NaN
# 29651  ['Lds Fiction', 'Historical Fiction', 'Young A...   201  ...  Romance
#
#                                                   tokens university  \
# 0      {'sentence', 'america', 'take', 'life', 'conte...         {}
# 1      {'strength', 'lot', 'ordinary', 'end', 'things...         {}
# 2      {'published', 'experience', 'roots', 'classicc...         {}
# 3      {'austens', 'wit', 'cover', 'austen', 'popular...         {}
# 4      {'positivefirst', 'himand', 'things', 'part', ...         {}
# ...                                                  ...        ...
# 29647  {'trilogy', 'continues', 'want', 'destroy', 'd...         {}
# 29648  {'david', 'desert', 'arrived', 'wants', 'cant'...         {}
# 29649  {'hurtles', 'yearold', 'life', 'david', 'night...         {}
# 29650  {'suspense', 'relic', 'near', 'vesuvius', 'evi...         {}
# 29651  {'raiders', 'danger', 'fray', 'part', 'turn', ...         {}
#
#       relationships break ups divorce wedding moving coming of age death
# 0                {}        {}      {}      {}     {}            {}    {}
# 1                {}        {}      {}      {}     {}            {}    {}
# 2                {}        {}      {}      {}     {}            {}    {}
# 3                {}        {}      {}      {}     {}            {}    {}
# 4                {}        {}      {}      {}     {}            {}    {}
# ...             ...       ...     ...     ...    ...           ...   ...
# 29647            {}        {}      {}      {}     {}            {}    {}
# 29648            {}        {}      {}      {}     {}            {}    {}
# 29649            {}        {}      {}      {}     {}            {}    {}
# 29650            {}        {}      {}      {}     {}            {}    {}
# 29651            {}        {}      {}      {}     {}            {}    {}
#
# [29652 rows x 31 columns]

# %%
#filter df to rows with non-empty sets
model_data['university'].value_counts()
# Out:
# {}    29652
# Name: university, dtype: int64

# %%
print('hello world')
# Out:
# hello world

# %%
uni_set = ['college', 'university', 'campus', 'academia']
model_data['tokens_list'] = list(model_data['tokens'])
model_data['tokens_list'].head()
# Out:
# 0    [winning, means, fame, fortunelosing, means, c...
# 1    [door, end, silent, corridor, haunting, harry,...
# 2    [unforgettable, novel, childhood, sleepy, sout...
# 3    [alternate, cover, edition, isbn, since, immed...
# 4    [three, things, absolutely, positivefirst, edw...
# Name: tokens_list, dtype: object

# %%
model_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                       bookId  \
# 0             0           0                     2767052-the-hunger-games
# 1             1           1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2             2           2                   2657.To_Kill_a_Mockingbird
# 3             3           3                     1885.Pride_and_Prejudice
# 4             4           4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# 4                            Stephenie Meyer
#
#                                          description         isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9.78044E+12
# 1  There is a door at the end of a silent corrido...  9.78044E+12
# 2  The unforgettable novel of a childhood in a sl...        1E+13
# 3  Alternate cover edition of ISBN 9780679783268S...        1E+13
# 4  About three things I was absolutely positive.\...  9.78032E+12
#
#                                               genres pages  ...  Fantasy  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374  ...  Fantasy
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870  ...  Fantasy
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...   324  ...      NaN
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...   279  ...      NaN
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501  ...  Fantasy
#
#   History  Dystopia Manga Thriller Graphic Novels  Romance  \
# 0     NaN  Dystopia   NaN      NaN            NaN  Romance
# 1     NaN       NaN   NaN      NaN            NaN      NaN
# 2     NaN       NaN   NaN      NaN            NaN      NaN
# 3     NaN       NaN   NaN      NaN            NaN  Romance
# 4     NaN       NaN   NaN      NaN            NaN  Romance
#
#                                               tokens  \
# 0  [winning, means, fame, fortunelosing, means, c...
# 1  [door, end, silent, corridor, haunting, harry,...
# 2  [unforgettable, novel, childhood, sleepy, sout...
# 3  [alternate, cover, edition, isbn, since, immed...
# 4  [three, things, absolutely, positivefirst, edw...
#
#                                          tokens_list  \
# 0  {'sentence', 'america', 'take', 'life', 'conte...
# 1  {'strength', 'lot', 'ordinary', 'end', 'things...
# 2  {'published', 'experience', 'roots', 'classicc...
# 3  {'austens', 'wit', 'cover', 'austen', 'popular...
# 4  {'positivefirst', 'himand', 'things', 'part', ...
#
#                                           university
# 0  [W, I, N, N, I, N, G,  , M, E, A, N, S,  , F, ...
# 1  [T, h, e, r, e,  , i, s,  , a,  , d, o, o, r, ...
# 2  [T, h, e,  , u, n, f, o, r, g, e, t, t, a, b, ...
# 3  [A, l, t, e, r, n, a, t, e,  , c, o, v, e, r, ...
# 4  [A, b, o, u, t,  , t, h, r, e, e,  , t, h, i, ...
#
# [5 rows x 25 columns]

# %%
model_data['university'] = model_data['tokens'].apply(lambda x: [item for item in x if item in uni_set])

# %%
model_data['university'].value_counts()
# Out:
# []                                                                    28620
# [college]                                                               589
# [university]                                                            206
# [college, college]                                                       59
# [campus]                                                                 41
# [university, university]                                                 23
# [college, university]                                                    19
# [college, campus]                                                        18
# [university, college]                                                    14
# [university, campus]                                                      6
# [campus, campus]                                                          6
# [college, college, college]                                               6
# [academia]                                                                5
# [college, university, campus]                                             4
# [university, university, college]                                         3
# [college, university, university]                                         3
# [university, university, university, university]                          2
# [campus, college]                                                         2
# [college, college, university]                                            2
# [college, campus, college]                                                2
# [college, college, campus]                                                2
# [college, university, college]                                            1
# [campus, college, college]                                                1
# [college, college, college, college, university, college]                 1
# [university, college, campus, university, campus, campus, college]        1
# [campus, college, campus]                                                 1
# [university, academia]                                                    1
# [university, college, campus]                                             1
# [college, college, college, university]                                   1
# [campus, campus, campus]                                                  1
# [campus, college, college, college]                                       1
# [university, university, university]                                      1
# [college, campus, campus]                                                 1
# [university, academia, university]                                        1
# [college, university, university, university]                             1
# [college, university, college, college, college]                          1
# [college, academia, college]                                              1
# [college, college, college, college]                                      1
# [academia, university]                                                    1
# [college, campus, college, campus]                                        1
# [university, college, university]                                         1
# Name: university, dtype: int64
