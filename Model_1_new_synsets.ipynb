# %% [markdown]
# # Model #1 Synonym & Library Extraction - Exact Match

# %%
import s3fs
import boto3
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')

import re
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/ec2-user/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Pull in Data From S3 Bucket

# %%
# csv file
#df_books_filtered = pd.read_csv('s3://ec2-jupyter-notebook-us-west-2-8c94c42abbd5478ca9a1a477613965a7/books_filtered.csv')
text_data = pd.read_csv('s3://book-data-ucb-capstone-s2022/books_filtered_colsreduced.csv')
print('Total Text DF size:', len(text_data))

model_data = pd.read_csv('s3://book-data-ucb-capstone-s2022/tokenized_data.csv')
print('Tokenized Text DF Size:', len(model_data))
# Out:
# Total Text DF size: 29652
# Tokenized Text DF Size: 29652

# %%
model_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                       bookId  \
# 0             0           0                     2767052-the-hunger-games
# 1             1           1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2             2           2                   2657.To_Kill_a_Mockingbird
# 3             3           3                     1885.Pride_and_Prejudice
# 4             4           4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# 4                            Stephenie Meyer
#
#                                          description         isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9.78044E+12
# 1  There is a door at the end of a silent corrido...  9.78044E+12
# 2  The unforgettable novel of a childhood in a sl...        1E+13
# 3  Alternate cover edition of ISBN 9780679783268S...        1E+13
# 4  About three things I was absolutely positive.\...  9.78032E+12
#
#                                               genres pages  ...  Childrens  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374  ...        NaN
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870  ...  Childrens
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...   324  ...        NaN
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...   279  ...        NaN
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501  ...        NaN
#
#   New Adult  Fantasy History  Dystopia Manga Thriller Graphic Novels  Romance  \
# 0       NaN  Fantasy     NaN  Dystopia   NaN      NaN            NaN  Romance
# 1       NaN  Fantasy     NaN       NaN   NaN      NaN            NaN      NaN
# 2       NaN      NaN     NaN       NaN   NaN      NaN            NaN      NaN
# 3       NaN      NaN     NaN       NaN   NaN      NaN            NaN  Romance
# 4       NaN  Fantasy     NaN       NaN   NaN      NaN            NaN  Romance
#
#                                               tokens
# 0  {'sentence', 'america', 'take', 'life', 'conte...
# 1  {'strength', 'lot', 'ordinary', 'end', 'things...
# 2  {'published', 'experience', 'roots', 'classicc...
# 3  {'austens', 'wit', 'cover', 'austen', 'popular...
# 4  {'positivefirst', 'himand', 'things', 'part', ...
#
# [5 rows x 23 columns]

# %%
#sample df
df_samp = model_data.sample(n=100)
df_samp.to_csv('100_random_sample.csv')

# %% [markdown]
# ## Preprocessing
# Skip this section if using preprocessed dataset

# %%
def preprocess_text(text):

  #lowercase text
  text_preprocessed = text.lower()
  #remove punctuation
  text_preprocessed = re.sub(r'[^a-zA-Z ]+', '', text_preprocessed)
  #tokenize for stopword removal
  text_preprocessed = word_tokenize(text_preprocessed)
  #remove stopwords
  text_preprocessed = [word for word in text_preprocessed if word not in stopwords.words('english')]
  #join to make string again
  #text_preprocessed = (" ").join(text_preprocessed)

  return text_preprocessed

# %%
# %%time
model_data['tokens'] = model_data['description'].apply(lambda x: preprocess_text(x))
# Out:
# CPU times: user 5min 15s, sys: 22.6 s, total: 5min 38s
# Wall time: 5min 38s

# %%
model_data['tokens'].head()
# Out:
# 0    [winning, means, fame, fortunelosing, means, c...
# 1    [door, end, silent, corridor, haunting, harry,...
# 2    [unforgettable, novel, childhood, sleepy, sout...
# 3    [alternate, cover, edition, isbn, since, immed...
# 4    [three, things, absolutely, positivefirst, edw...
# Name: tokens, dtype: object

# %%
#save dataset to csv
model_data.to_csv('tokenized_data.csv')
#upload dataset to s3 & google drive

# %% [markdown]
# ## Synsets

# %%
def create_synsets(event):
  
  synonym = [] 
    
  for synset in wordnet.synsets(event): 
      for i in synset.lemmas(): 
          synonym.append(i.name()) # add all the synonyms available 
    
  return synonym

# %%
#creating library dataframe


life_events = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 
               'moving', 'coming of age', 'death']

#create synsets for select events where decent synsets exist
relationship_list = create_synsets('go_steady') + ['relationship', 'kinship']
marriage_list = create_synsets('wedding') + create_synsets('marriage')

#replace underscore (_) with space
relationship_list = [i.replace("_", " ") for i in relationship_list]
marriage_list = [i.replace("_", " ") for i in marriage_list]

synsets = [['college', 'university', 'campus', 'academia'], 
           relationship_list, 
           ['breakup', 'break up', 'split', 'split up', 'broken up', 'dumped'], 
           ['divorce', 'divorced', 'separate', 'separated'], 
           marriage_list, 
           ['move', 'moving'], 
           ['coming of age', 'growing up'], 
           ['death', 'decease', 'deceased', 'dying']]

# Create the pandas DataFrame with column name is provided explicitly
df_lib = pd.DataFrame(life_events, columns=['life_event'])
df_lib['synsets'] = synsets
 
# print dataframe.
df_lib
# Out:
#       life_event                                            synsets
# 0     university            [college, university, campus, academia]
# 1  relationships  [go steady, go out, date, see, relationship, k...
# 2      break ups  [breakup, break up, split, split up, broken up...
# 3        divorce           [divorce, divorced, separate, separated]
# 4        wedding  [wedding, wedding ceremony, nuptials, hymeneal...
# 5         moving                                     [move, moving]
# 6  coming of age                        [coming of age, growing up]
# 7          death                  [death, decease, deceased, dying]

# %% [markdown]
# ## Match Tokens to Libraries

# %%
def match_tokens_to_libraries(df_syn, life_event, df_model, token_col):
    
    #match list of synsets to events
    syn_list = df_syn['synsets'][df_syn.life_event==life_event].item()
    print(syn_list)
    #pull out synset matches
    df_model[life_event] = df_model[token_col].apply(lambda x: [item for item in x if item in syn_list])
    #dedupe events
    df_model[life_event] = df_model[life_event].apply(lambda x: list(set(x)))
    
    return df_model[life_event]

# %%
#test one example
model_data['university'] = match_tokens_to_libraries(df_lib, 'university', model_data, 'tokens')
model_data['university'].value_counts()
# Out:
# ['college', 'university', 'campus', 'academia']
# []                               28620
# [college]                          655
# [university]                       232
# [campus]                            48
# [university, college]               47
# [campus, college]                   29
# [university, campus, college]        6
# [university, campus]                 6
# [academia]                           5
# [university, academia]               3
# [academia, college]                  1
# Name: university, dtype: int64

# %%
#apply function for all life events
life_events = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 
               'moving', 'coming of age', 'death']

for event in life_events:
    print(event)
    model_data[event] = match_tokens_to_libraries(df_lib, event, model_data, 'tokens')
# Out:
# university
# ['college', 'university', 'campus', 'academia']
# relationships
# ['go steady', 'go out', 'date', 'see', 'relationship', 'kinship']
# break ups
# ['breakup', 'break up', 'split', 'split up', 'broken up', 'dumped']
# divorce
# ['divorce', 'divorced', 'separate', 'separated']
# wedding
# ['wedding', 'wedding ceremony', 'nuptials', 'hymeneals', 'marriage', 'wedding', 'marriage ceremony', 'wedding', 'wedding party', 'marry', 'get married', 'wed', 'conjoin', 'hook up with', 'get hitched with', 'espouse', 'marry', 'wed', 'tie', 'splice', 'marriage', 'matrimony', 'union', 'spousal relationship', 'wedlock', 'marriage', 'married couple', 'man and wife', 'marriage', 'wedding', 'marriage ceremony', 'marriage']
# moving
# ['move', 'moving']
# coming of age
# ['coming of age', 'growing up']
# death
# ['death', 'decease', 'deceased', 'dying']

# %% [markdown]
# ### Check Events

# %%
model_data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                                       bookId  \
# 0             0           0                     2767052-the-hunger-games
# 1             1           1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2             2           2                   2657.To_Kill_a_Mockingbird
# 3             3           3                     1885.Pride_and_Prejudice
# 4             4           4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# 4                            Stephenie Meyer
#
#                                          description         isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9.78044E+12
# 1  There is a door at the end of a silent corrido...  9.78044E+12
# 2  The unforgettable novel of a childhood in a sl...        1E+13
# 3  Alternate cover edition of ISBN 9780679783268S...        1E+13
# 4  About three things I was absolutely positive.\...  9.78032E+12
#
#                                               genres pages  ...  Romance  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374  ...  Romance
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870  ...      NaN
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...   324  ...      NaN
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...   279  ...  Romance
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501  ...  Romance
#
#                                               tokens university relationships  \
# 0  [winning, means, fame, fortunelosing, means, c...         []            []
# 1  [door, end, silent, corridor, haunting, harry,...         []            []
# 2  [unforgettable, novel, childhood, sleepy, sout...         []            []
# 3  [alternate, cover, edition, isbn, since, immed...         []            []
# 4  [three, things, absolutely, positivefirst, edw...         []            []
#
#   break ups divorce wedding    moving coming of age    death
# 0        []      []      []        []            []  [death]
# 1        []      []      []        []            []       []
# 2        []      []      []  [moving]            []       []
# 3        []      []      []        []            []       []
# 4        []      []      []        []            []       []
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Next Steps - Model 1
# * add bigrams & trigrams to tokens (nltk)
# * revisit stopword removal
# * remove coming of age category
# * restructure moving category
# * add family category (familial relationships, likely manual list)
# * library optimization
# * create programmatic evaluation set / test set
# * similarity scoring
#
# ## Next Steps - Code-wise
# * EDA (Amber)
# * Model 2 discussion - Tuesday
#
# ## Next Steps - UI

# %%
#save results to csv
model_data.to_csv('results_model1.csv')

# %% [markdown]
# ## Evaluation

# %%
#import eval set from s3
test_set = pd.read_csv('s3://book-data-ucb-capstone-s2022/100_random_sample - 100_random_sample.csv')
test_set.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                            bookId  \
# 0           676         807               78983.Kane_and_Abel
# 1         21181       36647              17256423-coming-home
# 2         14151       21701     868.Fullmetal_Alchemist_Vol_3
# 3         10603       14874           17063691-island-of-fire
# 4          8952       12363  34433755-girls-of-paper-and-fire
#
#                          title                      series  \
# 0                Kane and Abel              Kane & Abel #1
# 1                  Coming Home                         NaN
# 2  Fullmetal Alchemist, Vol. 3      Fullmetal Alchemist #3
# 3               Island of Fire                Unwanteds #3
# 4      Girls of Paper and Fire  Girls of Paper and Fire #1
#
#                                               author  \
# 0                                     Jeffrey Archer
# 1                       E.M. Leya (Goodreads Author)
# 2        Hiromu Arakawa, Akira Watanabe (Translator)
# 3                     Lisa McMann (Goodreads Author)
# 4  Natasha Ngan (Goodreads Author), James Patters...
#
#                                          description        isbn  \
# 0  Born on the same day near the turn of the cent...    9.78E+12
# 1  Mitch left town eight years ago and never look...  B00B1Z02NS
# 2  Accompanied by their bodyguard, Alex Louis Arm...    9.78E+12
# 3  The fate of Artimé is at stake - and an unlike...    9.78E+12
# 4  Each year, eight beautiful girls are chosen as...    9.78E+12
#
#                                               genres  pages  ... University_T  \
# 0  ['Fiction', 'Historical Fiction', 'Thriller', ...  592.0  ...        False
# 1    ['M M Romance', 'Military Fiction', 'Westerns']  152.0  ...          NaN
# 2  ['Manga', 'Fantasy', 'Comics', 'Graphic Novels...  192.0  ...          NaN
# 3  ['Fantasy', 'Middle Grade', 'Young Adult', 'Fi...  464.0  ...          NaN
# 4  ['Fantasy', 'Young Adult', 'LGBT', 'Romance', ...  385.0  ...          NaN
#
#   Relationships_T Break_ups_T Divorce_T Wedding_T Moving_T  Coming_of_age_T  \
# 0           False       False     False     False     True            False
# 1             NaN         NaN       NaN       NaN     True              NaN
# 2             NaN         NaN       NaN       NaN      NaN              NaN
# 3             NaN         NaN       NaN       NaN      NaN              NaN
# 4            True         NaN       NaN       NaN      NaN              NaN
#
#   Death_T Family_T Friendship_T
# 0   False    False        False
# 1     NaN     True         True
# 2     NaN      NaN         True
# 3     NaN     True          NaN
# 4     NaN     True          NaN
#
# [5 rows x 34 columns]

# %%
test_set.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'bookId', 'title', 'series', 'author',
#        'description', 'isbn', 'genres', 'pages', 'publishDate', 'Fiction',
#        'Young Adult', 'Childrens', 'New Adult', 'Fantasy', 'History',
#        'Dystopia', 'Manga', 'Thriller', 'Graphic Novels', 'Romance', 'tokens',
#        'Life Event Categories', 'University_T', 'Relationships_T',
#        'Break_ups_T', 'Divorce_T', 'Wedding_T', 'Moving_T', 'Coming_of_age_T',
#        'Death_T', 'Family_T', 'Friendship_T'],
#       dtype='object')

# %%
#reduce test set cols
test_set = test_set[['bookId', 'Life Event Categories', 'University_T', 'Relationships_T',
       'Break_ups_T', 'Divorce_T', 'Wedding_T', 'Moving_T', 'Coming_of_age_T',
       'Death_T', 'Family_T', 'Friendship_T']]

# %%
#join model results on test set
df_test_results = pd.merge(model_data, test_set, on='bookId', how='inner')
print(len(df_test_results))
# Out:
# 100

# %%
df_test_results.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                    bookId               title  \
# 0           424         496     6644117-the-iron-king       The Iron King
# 1           676         807       78983.Kane_and_Abel       Kane and Abel
# 2           848        1017    14817.A_Scanner_Darkly    A Scanner Darkly
# 3           962        1159  42156.Something_Borrowed  Something Borrowed
# 4          1228        1510      6587387-silver-borne        Silver Borne
#
#               series                           author  \
# 0    The Iron Fey #1  Julie Kagawa (Goodreads Author)
# 1     Kane & Abel #1                   Jeffrey Archer
# 2                NaN                   Philip K. Dick
# 3  Darcy & Rachel #1  Emily Giffin (Goodreads Author)
# 4  Mercy Thompson #5                  Patricia Briggs
#
#                                          description         isbn  \
# 0  Meghan Chase has a secret destiny; one she cou...  9.78037E+12
# 1  Born on the same day near the turn of the cent...  9.78031E+12
# 2  Substance D is not known as Death for nothing....  9.78058E+12
# 3  Something Borrowed tells the story of Rachel, ...  9.78031E+12
# 4  Mercy Thompson, car mechanic and shapeshifter,...  9.78044E+12
#
#                                               genres pages  ... University_T  \
# 0  ['Fantasy', 'Young Adult', 'Romance', 'Paranor...   363  ...          NaN
# 1  ['Fiction', 'Historical Fiction', 'Thriller', ...   592  ...        False
# 2  ['Science Fiction', 'Fiction', 'Dystopia', 'Sc...   219  ...        False
# 3  ['Chick Lit', 'Romance', 'Fiction', 'Contempor...   322  ...          NaN
# 4  ['Urban Fantasy', 'Fantasy', 'Paranormal', 'Ro...   342  ...          NaN
#
#   Relationships_T Break_ups_T Divorce_T Wedding_T Moving_T Coming_of_age_T  \
# 0             NaN         NaN       NaN       NaN      NaN             NaN
# 1           False       False     False     False     True           False
# 2           False       False     False     False      NaN           False
# 3            True        True     False      True      NaN             NaN
# 4             NaN         NaN       NaN       NaN      NaN             NaN
#
#   Death_T Family_T Friendship_T
# 0     NaN     True         True
# 1   False    False        False
# 2   False    False        False
# 3     NaN      NaN         True
# 4     NaN      NaN         True
#
# [5 rows x 42 columns]

# %%
df_test_results.to_csv('test_results_model1v0.csv')
