# %%
import pandas as pd
import numpy as np
import io
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_excel('/content/drive/My Drive/all_books_excel.xlsx')
# Out:
# Mounted at /content/drive

# %%
df
# Out:
#               #           ?  \
# 0           620     /m/0hhy
# 1           843     /m/0k36
# 2           986     /m/0ldx
# 3          1756     /m/0sww
# 4          2080     /m/0wkt
# ...         ...         ...
# 16561  36934824  /m/0m0p0hr
# 16562  37054020  /m/04f1nbs
# 16563  37122323  /m/0n5236t
# 16564  37132319  /m/0n4bqb1
# 16565  37159503   /m/073nkd
#
#                                               Book Title              Author  \
# 0                                            Animal Farm       George Orwell
# 1                                     A Clockwork Orange     Anthony Burgess
# 2                                             The Plague        Albert Camus
# 3              An Enquiry Concerning Human Understanding          David Hume
# 4                                   A Fire Upon the Deep        Vernor Vinge
# ...                                                  ...                 ...
# 16561                                     Under Wildwood         Colin Meloy
# 16562                                  Transfer of Power         Vince Flynn
# 16563                                            Decoded               Jay-Z
# 16564  America Again: Re-becoming The Greatness We Ne...     Stephen Colbert
# 16565                                          Poor Folk  Fyodor Dostoyevsky
#
#           Published Date?                                                JSON  \
# 0      1945-08-17 00:00:00  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1                     1962  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2                     1947  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3                      NaN                                                NaN
# 4                      NaN  {"/m/03lrw": "Hard science fiction", "/m/06n90...
# ...                    ...                                                ...
# 16561  2012-09-25 00:00:00                                                NaN
# 16562  2000-06-01 00:00:00   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
# 16563  2010-11-16 00:00:00                       {"/m/0xdf": "Autobiography"}
# 16564  2012-10-02 00:00:00                                                NaN
# 16565                 1846  {"/m/02ql9": "Epistolary novel", "/m/014dfn": ...
#
#                                                Synopsis
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16561   Prue McKeel, having rescued her brother from ...
# 16562   The reader first meets Rapp while he is doing...
# 16563   The book follows very rough chronological ord...
# 16564   Colbert addresses topics including Wall Stree...
# 16565   Makar Devushkin and Varvara Dobroselova are s...
#
# [16566 rows x 7 columns]

# %% [markdown]
# Filtering df
#
# 1. df_clean = Remove blank fields - create separate dataframe
# 2. df_filter_1 = Remove JSON that contains: religious text, philosophy, science, autobiography, memoir, biography, computer science, existentialism, just history, reference, nature, religion, economics, mathematics, science, sociology, business, essay, metaphysics, spirituality, self-help, true crime
# 3. df_filter_2 = Filter whole df for containing: fiction, novel, novella, poetry, children’s literature, mystery, thriller, story, wuxi, comedy, comic, satire, role playing game, western, parody

# %%
df_clean = df.dropna(subset=['JSON'])
df_filter_1 = df_clean[df_clean["JSON"].str.contains('Religious text|Philosophy|Science|Autobiography|Memoir|Biography|Computer science|Existentialism|Reference|Nature|Religion|Economics|Mathematics|Science|Sociology|Business|Essay|Metaphysics|Spirituality|Self-help|True crime|History')==False]
df_filter_2 = df_clean[df_clean['JSON'].str.contains("Fiction|Novel|Novella|Poetry|Children’s literature|Mystery|Thriller|Story|Wuxi|Comedy|Comic|Satire|Role playing game|Western|Parody")]

# %%
df_clean
# Out:
#               #           ?                      Book Title  \
# 0           620     /m/0hhy                     Animal Farm
# 1           843     /m/0k36              A Clockwork Orange
# 2           986     /m/0ldx                      The Plague
# 4          2080     /m/0wkt            A Fire Upon the Deep
# 5          2152     /m/0x5g  All Quiet on the Western Front
# ...         ...         ...                             ...
# 16556  36372465  /m/02vqwsp                  The Third Lynx
# 16558  36534061   /m/072y44                  Remote Control
# 16562  37054020  /m/04f1nbs               Transfer of Power
# 16563  37122323  /m/0n5236t                         Decoded
# 16565  37159503   /m/073nkd                       Poor Folk
#
#                      Author     Published Date?   \
# 0             George Orwell  1945-08-17 00:00:00
# 1           Anthony Burgess                 1962
# 2              Albert Camus                 1947
# 4              Vernor Vinge                  NaN
# 5      Erich Maria Remarque  1929-01-29 00:00:00
# ...                     ...                  ...
# 16556          Timothy Zahn                 2007
# 16558            Andy McNab                 1997
# 16562           Vince Flynn  2000-06-01 00:00:00
# 16563                 Jay-Z  2010-11-16 00:00:00
# 16565    Fyodor Dostoyevsky                 1846
#
#                                                     JSON  \
# 0      {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1      {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2      {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 4      {"/m/03lrw": "Hard science fiction", "/m/06n90...
# 5      {"/m/098tmk": "War novel", "/m/016lj8": "Roman...
# ...                                                  ...
# 16556                    {"/m/06n90": "Science Fiction"}
# 16558  {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction...
# 16562   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
# 16563                       {"/m/0xdf": "Autobiography"}
# 16565  {"/m/02ql9": "Epistolary novel", "/m/014dfn": ...
#
#                                                Synopsis
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 4       The novel posits that space around the Milky ...
# 5       The book tells the story of Paul Bäumer, a Ge...
# ...                                                  ...
# 16556   The story starts with former government agent...
# 16558   The series follows the character of Nick Ston...
# 16562   The reader first meets Rapp while he is doing...
# 16563   The book follows very rough chronological ord...
# 16565   Makar Devushkin and Varvara Dobroselova are s...
#
# [12841 rows x 7 columns]

# %%
df_filter_1
# Out:
#               #           ?                      Book Title  \
# 0           620     /m/0hhy                     Animal Farm
# 5          2152     /m/0x5g  All Quiet on the Western Front
# 6          2890    /m/011zx            A Wizard of Earthsea
# 20         6020    /m/01t5z                           Crash
# 22         6629    /m/01y9j         Candide, ou l'Optimisme
# ...         ...         ...                             ...
# 16552  36126601   /m/0dh1vx                      Dark Angel
# 16553  36126792   /m/044psh               Gates of Paradise
# 16558  36534061   /m/072y44                  Remote Control
# 16562  37054020  /m/04f1nbs               Transfer of Power
# 16565  37159503   /m/073nkd                       Poor Folk
#
#                      Author     Published Date?   \
# 0             George Orwell  1945-08-17 00:00:00
# 5      Erich Maria Remarque  1929-01-29 00:00:00
# 6         Ursula K. Le Guin                 1968
# 20            J. G. Ballard                 1973
# 22                 Voltaire              1759-01
# ...                     ...                  ...
# 16552         V. C. Andrews              1986-11
# 16553         V. C. Andrews              1989-06
# 16558            Andy McNab                 1997
# 16562           Vince Flynn  2000-06-01 00:00:00
# 16565    Fyodor Dostoyevsky                 1846
#
#                                                     JSON  \
# 0      {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 5      {"/m/098tmk": "War novel", "/m/016lj8": "Roman...
# 6      {"/m/0dwly": "Children's literature", "/m/01hm...
# 20     {"/m/014dfn": "Speculative fiction", "/m/02xlf...
# 22     {"/m/06nbt": "Satire", "/m/01jym": "Bildungsro...
# ...                                                  ...
# 16552  {"/m/039vk": "Gothic fiction", "/m/03mfnf": "Y...
# 16553  {"/m/039vk": "Gothic fiction", "/m/03mfnf": "Y...
# 16558  {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction...
# 16562   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
# 16565  {"/m/02ql9": "Epistolary novel", "/m/014dfn": ...
#
#                                                Synopsis
# 0       Old Major, the old boar on the Manor Farm, ca...
# 5       The book tells the story of Paul Bäumer, a Ge...
# 6       Ged is a young boy on Gont, one of the larger...
# 20      The story is told through the eyes of narrato...
# 22      Candide contains thirty episodic chapters, wh...
# ...                                                  ...
# 16552   After the events of Heaven (the first book in...
# 16553   A novel about Annie Stonewall, the daughter o...
# 16558   The series follows the character of Nick Ston...
# 16562   The reader first meets Rapp while he is doing...
# 16565   Makar Devushkin and Varvara Dobroselova are s...
#
# [9506 rows x 7 columns]

# %%
df_filter_2
# Out:
#               #           ?             Book Title             Author  \
# 0           620     /m/0hhy            Animal Farm      George Orwell
# 1           843     /m/0k36     A Clockwork Orange    Anthony Burgess
# 2           986     /m/0ldx             The Plague       Albert Camus
# 4          2080     /m/0wkt   A Fire Upon the Deep       Vernor Vinge
# 6          2890    /m/011zx   A Wizard of Earthsea  Ursula K. Le Guin
# ...         ...         ...                    ...                ...
# 16549  35993963  /m/0jzxgsx  The Bourne Imperative      Robert Ludlum
# 16551  36126507   /m/0dh1sv                 Heaven      V. C. Andrews
# 16556  36372465  /m/02vqwsp         The Third Lynx       Timothy Zahn
# 16558  36534061   /m/072y44         Remote Control         Andy McNab
# 16562  37054020  /m/04f1nbs      Transfer of Power        Vince Flynn
#
#           Published Date?                                                JSON  \
# 0      1945-08-17 00:00:00  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1                     1962  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2                     1947  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 4                      NaN  {"/m/03lrw": "Hard science fiction", "/m/06n90...
# 6                     1968  {"/m/0dwly": "Children's literature", "/m/01hm...
# ...                    ...                                                ...
# 16549  2012-06-05 00:00:00  {"/m/01jfsb": "Thriller", "/m/06wkf": "Spy fic...
# 16551  1985-10-15 00:00:00  {"/m/039vk": "Gothic fiction", "/m/03mfnf": "Y...
# 16556                 2007                    {"/m/06n90": "Science Fiction"}
# 16558                 1997  {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction...
# 16562  2000-06-01 00:00:00   {"/m/01jfsb": "Thriller", "/m/02xlf": "Fiction"}
#
#                                                Synopsis
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 4       The novel posits that space around the Milky ...
# 6       Ged is a young boy on Gont, one of the larger...
# ...                                                  ...
# 16549   :For a more detailed background of the main c...
# 16551   Heaven Leigh Casteel is a fourteen year old g...
# 16556   The story starts with former government agent...
# 16558   The series follows the character of Nick Ston...
# 16562   The reader first meets Rapp while he is doing...
#
# [8917 rows x 7 columns]

# %%
df_comb = pd.concat([df_filter_1,df_filter_2]).drop_duplicates().reset_index(drop=True)

# %%
df_comb
# Out:
#               #           ?                      Book Title  \
# 0           620     /m/0hhy                     Animal Farm
# 1          2152     /m/0x5g  All Quiet on the Western Front
# 2          2890    /m/011zx            A Wizard of Earthsea
# 3          6020    /m/01t5z                           Crash
# 4          6629    /m/01y9j         Candide, ou l'Optimisme
# ...         ...         ...                             ...
# 12533  34030507  /m/0hr6q54                   Earth Unaware
# 12534  34260936  /m/0hzp_h5        Death Comes to Pemberley
# 12535  34360364  /m/0h_d2by              She Lover of Death
# 12536  34621656  /m/0j28_b0        The Twilight of Briareus
# 12537  36372465  /m/02vqwsp                  The Third Lynx
#
#                           Author     Published Date?   \
# 0                  George Orwell  1945-08-17 00:00:00
# 1           Erich Maria Remarque  1929-01-29 00:00:00
# 2              Ursula K. Le Guin                 1968
# 3                  J. G. Ballard                 1973
# 4                       Voltaire              1759-01
# ...                          ...                  ...
# 12533             Aaron Johnston                  NaN
# 12534                P. D. James  2011-12-06 00:00:00
# 12535               Boris Akunin                  NaN
# 12536  John Middleton Murry, Jr.                 1974
# 12537               Timothy Zahn                 2007
#
#                                                     JSON  \
# 0      {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1      {"/m/098tmk": "War novel", "/m/016lj8": "Roman...
# 2      {"/m/0dwly": "Children's literature", "/m/01hm...
# 3      {"/m/014dfn": "Speculative fiction", "/m/02xlf...
# 4      {"/m/06nbt": "Satire", "/m/01jym": "Bildungsro...
# ...                                                  ...
# 12533                    {"/m/06n90": "Science Fiction"}
# 12534  {"/m/02n4kr": "Mystery", "/m/0py65": "Historic...
# 12535  {"/m/02n4kr": "Mystery", "/m/05hgj": "Novel", ...
# 12536                    {"/m/06n90": "Science Fiction"}
# 12537                    {"/m/06n90": "Science Fiction"}
#
#                                                Synopsis
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       The book tells the story of Paul Bäumer, a Ge...
# 2       Ged is a young boy on Gont, one of the larger...
# 3       The story is told through the eyes of narrato...
# 4       Candide contains thirty episodic chapters, wh...
# ...                                                  ...
# 12533   A clan of "free miners" living on the spacesh...
# 12534   The novel begins in October, 1803, six years ...
# 12535   A naive young woman, Masha Mironova, travels ...
# 12536   Briareus Delta becomes a supernova only about...
# 12537   The story starts with former government agent...
#
# [12538 rows x 7 columns]

# %%
BBE = pd.read_csv('/content/drive/My Drive/books_1.Best_Books_Ever.csv')

# %%
BBE
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son                    NaN
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      9999999999999  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...              ...                                                ...
# 52473  2940012616562  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...
# 52474  9999999999999                         ['Mystery', 'Young Adult']
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  ...  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...
# ...                                                  ...  ...
# 52473                                                 []  ...
# 52474                                                 []  ...
# 52475                                                 []  ...
# 52476                                                 []  ...
# 52477                                                 []  ...
#
#       firstPublishDate                                             awards  \
# 0                  NaN  ['Locus Award Nominee for Best Young Adult Boo...
# 1             06/21/03  ['Bram Stoker Award for Works for Young Reader...
# 2             07/11/60  ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 3             01/28/13                                                 []
# 4             10/05/05  ['Georgia Peach Book Award (2007)', 'Buxtehude...
# ...                ...                                                ...
# 52473              NaN                                                 []
# 52474  August 3rd 2011                                                 []
# 52475  March 15th 2011            ["Readers' Favorite Book Award (2011)"]
# 52476   April 5th 2011                                                 []
# 52477              NaN                                                 []
#
#       numRatings                                     ratingsByStars  \
# 0        6376780  ['3444695', '1921313', '745221', '171994', '93...
# 1        2507623  ['1593642', '637516', '222366', '39573', '14526']
# 2        4501075  ['2363896', '1333153', '573280', '149952', '80...
# 3        2998241  ['1617567', '816659', '373311', '113934', '767...
# 4        4964519  ['1751460', '1113682', '1008686', '542017', '5...
# ...          ...                                                ...
# 52473        871                  ['311', '310', '197', '42', '11']
# 52474         37                        ['16', '14', '5', '2', '0']
# 52475       6674             ['2109', '1868', '1660', '647', '390']
# 52476        238                      ['77', '78', '59', '19', '5']
# 52477        246                     ['106', '73', '42', '17', '8']
#
#       likedPercent                                            setting  \
# 0             96.0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1             98.0  ['Hogwarts School of Witchcraft and Wizardry (...
# 2             95.0               ['Maycomb, Alabama (United States)']
# 3             94.0  ['United Kingdom', 'Derbyshire, England (Unite...
# 4             78.0  ['Forks, Washington (United States)', 'Phoenix...
# ...            ...                                                ...
# 52473         94.0                                                 []
# 52474         95.0                                                 []
# 52475         84.0                                                 []
# 52476         90.0                                                 []
# 52477         90.0                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516
# 1      https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923
# 2      https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328
# 3      https://i.gr-assets.com/images/S/compressed.ph...   1983116    20452
# 4      https://i.gr-assets.com/images/S/compressed.ph...   1459448    14874
# ...                                                  ...       ...      ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...         0        1
#
#        price
# 0       5.09
# 1       7.38
# 2        NaN
# 3        NaN
# 4        2.1
# ...      ...
# 52473    NaN
# 52474    NaN
# 52475   7.37
# 52476   2.86
# 52477   5.20
#
# [52478 rows x 25 columns]

# %%
BBE_filtered = BBE[BBE['genres'].str.contains("Young Adult|Fiction")]

# %%
BBE_filtered
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son                    NaN
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      9999999999999  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...              ...                                                ...
# 52473  2940012616562  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...
# 52474  9999999999999                         ['Mystery', 'Young Adult']
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  ...  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...
# ...                                                  ...  ...
# 52473                                                 []  ...
# 52474                                                 []  ...
# 52475                                                 []  ...
# 52476                                                 []  ...
# 52477                                                 []  ...
#
#       firstPublishDate                                             awards  \
# 0                  NaN  ['Locus Award Nominee for Best Young Adult Boo...
# 1             06/21/03  ['Bram Stoker Award for Works for Young Reader...
# 2             07/11/60  ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 3             01/28/13                                                 []
# 4             10/05/05  ['Georgia Peach Book Award (2007)', 'Buxtehude...
# ...                ...                                                ...
# 52473              NaN                                                 []
# 52474  August 3rd 2011                                                 []
# 52475  March 15th 2011            ["Readers' Favorite Book Award (2011)"]
# 52476   April 5th 2011                                                 []
# 52477              NaN                                                 []
#
#       numRatings                                     ratingsByStars  \
# 0        6376780  ['3444695', '1921313', '745221', '171994', '93...
# 1        2507623  ['1593642', '637516', '222366', '39573', '14526']
# 2        4501075  ['2363896', '1333153', '573280', '149952', '80...
# 3        2998241  ['1617567', '816659', '373311', '113934', '767...
# 4        4964519  ['1751460', '1113682', '1008686', '542017', '5...
# ...          ...                                                ...
# 52473        871                  ['311', '310', '197', '42', '11']
# 52474         37                        ['16', '14', '5', '2', '0']
# 52475       6674             ['2109', '1868', '1660', '647', '390']
# 52476        238                      ['77', '78', '59', '19', '5']
# 52477        246                     ['106', '73', '42', '17', '8']
#
#       likedPercent                                            setting  \
# 0             96.0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1             98.0  ['Hogwarts School of Witchcraft and Wizardry (...
# 2             95.0               ['Maycomb, Alabama (United States)']
# 3             94.0  ['United Kingdom', 'Derbyshire, England (Unite...
# 4             78.0  ['Forks, Washington (United States)', 'Phoenix...
# ...            ...                                                ...
# 52473         94.0                                                 []
# 52474         95.0                                                 []
# 52475         84.0                                                 []
# 52476         90.0                                                 []
# 52477         90.0                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516
# 1      https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923
# 2      https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328
# 3      https://i.gr-assets.com/images/S/compressed.ph...   1983116    20452
# 4      https://i.gr-assets.com/images/S/compressed.ph...   1459448    14874
# ...                                                  ...       ...      ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...         0        1
#
#        price
# 0       5.09
# 1       7.38
# 2        NaN
# 3        NaN
# 4        2.1
# ...      ...
# 52473    NaN
# 52474    NaN
# 52475   7.37
# 52476   2.86
# 52477   5.20
#
# [34950 rows x 25 columns]

# %%
BBE_filtered_2 = BBE[(BBE['genres'].str.contains('Fiction')) & (BBE['genres'].str.contains('Young Adult'))]

# %%
BBE_filtered_2
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 4                                   41865.Twilight
# 5                             19063.The_Book_Thief
# ...                                            ...
# 52453                         15534.Question_Quest
# 52466       8756401-theodosia-and-the-last-pharaoh
# 52471                           12464361-elemental
# 52475                              10815662-marked
# 52477                 10991547-daughter-of-helaman
#
#                                            title                     series  \
# 0                               The Hunger Games        The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix            Harry Potter #5
# 2                          To Kill a Mockingbird      To Kill a Mockingbird
# 4                                       Twilight       The Twilight Saga #1
# 5                                 The Book Thief                        NaN
# ...                                          ...                        ...
# 52453                             Question Quest                  Xanth #14
# 52466             Theodosia and the Last Pharaoh  Theodosia Throckmorton #4
# 52471                                  Elemental          Soul Guardians #2
# 52475                                     Marked          Soul Guardians #1
# 52477                        Daughter of Helaman       Stripling Warrior #1
#
#                                           author  rating  \
# 0                                Suzanne Collins    4.33
# 1      J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                     Harper Lee    4.28
# 4                                Stephenie Meyer    3.60
# 5                Markus Zusak (Goodreads Author)    4.37
# ...                                          ...     ...
# 52453                              Piers Anthony    3.72
# 52466           R.L. LaFevers (Goodreads Author)    4.26
# 52471          Kim Richardson (Goodreads Author)    4.07
# 52475          Kim Richardson (Goodreads Author)    3.70
# 52477            Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 4      About three things I was absolutely positive.\...  English
# 5      Librarian's note: An alternate cover edition c...  English
# ...                                                  ...      ...
# 52453  Youth is Wasted on the Young  Being grown up i...  English
# 52466  In this fourth book in the series, Theodosia s...  English
# 52471  When seventeen-year-old Kara Nightingale is su...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 5      9780375831003  ['Historical Fiction', 'Fiction', 'Young Adult...
# ...              ...                                                ...
# 52453  9780380759484  ['Fantasy', 'Fiction', 'Humor', 'Science Ficti...
# 52466  9780547390185  ['Fantasy', 'Middle Grade', 'Mystery', 'Histor...
# 52471     B005IGOSCC  ['Fantasy', 'Young Adult', 'Angels', 'Romance'...
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  ...  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...
# 5      ['Liesel Meminger', 'Hans Hubermann', 'Rudy St...  ...
# ...                                                  ...  ...
# 52453                                                 []  ...
# 52466                                                 []  ...
# 52471                                                 []  ...
# 52475                                                 []  ...
# 52477                                                 []  ...
#
#        firstPublishDate                                             awards  \
# 0                   NaN  ['Locus Award Nominee for Best Young Adult Boo...
# 1              06/21/03  ['Bram Stoker Award for Works for Young Reader...
# 2              07/11/60  ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 4              10/05/05  ['Georgia Peach Book Award (2007)', 'Buxtehude...
# 5              09/01/05  ['National Jewish Book Award for Children’s an...
# ...                 ...                                                ...
# 52453              1991                                                 []
# 52466  January 1st 2011                                                 []
# 52471   August 1st 2011                                                 []
# 52475   March 15th 2011            ["Readers' Favorite Book Award (2011)"]
# 52477               NaN                                                 []
#
#       numRatings                                     ratingsByStars  \
# 0        6376780  ['3444695', '1921313', '745221', '171994', '93...
# 1        2507623  ['1593642', '637516', '222366', '39573', '14526']
# 2        4501075  ['2363896', '1333153', '573280', '149952', '80...
# 4        4964519  ['1751460', '1113682', '1008686', '542017', '5...
# 5        1834276  ['1048230', '524674', '186297', '48864', '26211']
# ...          ...                                                ...
# 52453       7148              ['1815', '2239', '2442', '553', '99']
# 52466       1958                  ['920', '708', '262', '48', '20']
# 52471       1947                  ['801', '636', '391', '84', '35']
# 52475       6674             ['2109', '1868', '1660', '647', '390']
# 52477        246                     ['106', '73', '42', '17', '8']
#
#       likedPercent                                            setting  \
# 0             96.0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1             98.0  ['Hogwarts School of Witchcraft and Wizardry (...
# 2             95.0               ['Maycomb, Alabama (United States)']
# 4             78.0  ['Forks, Washington (United States)', 'Phoenix...
# 5             96.0                  ['Molching (Germany)', 'Germany']
# ...            ...                                                ...
# 52453         91.0                                                 []
# 52466         97.0                                                 []
# 52471         94.0                                                 []
# 52475         84.0                                                 []
# 52477         90.0                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516
# 1      https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923
# 2      https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328
# 4      https://i.gr-assets.com/images/S/compressed.ph...   1459448    14874
# 5      https://i.gr-assets.com/images/S/compressed.ph...   1372809    14168
# ...                                                  ...       ...      ...
# 52453  https://i.gr-assets.com/images/S/compressed.ph...         1        1
# 52466  https://i.gr-assets.com/images/S/compressed.ph...         1        1
# 52471  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...         0        1
#
#        price
# 0       5.09
# 1       7.38
# 2        NaN
# 4        2.1
# 5        3.8
# ...      ...
# 52453   4.45
# 52466   7.92
# 52471    NaN
# 52475   7.37
# 52477   5.20
#
# [10543 rows x 25 columns]

# %%
BBE_NF = BBE[BBE['genres'].str.contains('Nonfiction')]

# %%
BBE_NF
# Out:
#                               bookId  \
# 86             252577.Angela_s_Ashes
# 122        6900.Tuesdays_with_Morrie
# 129             168642.In_Cold_Blood
# 158              19501.Eat_Pray_Love
# 207          375013.Schindler_s_List
# ...                              ...
# 52456     2088519.Sex_at_the_Margins
# 52458        2147003.Mission_to_Asia
# 52459  797498.The_Last_Three_Minutes
# 52464             36374396-algedonic
# 52469          270435.Heal_Your_Body
#
#                                                    title  \
# 86                                        Angela's Ashes
# 122                                 Tuesdays with Morrie
# 129                                        In Cold Blood
# 158                                      Eat, Pray, Love
# 207                                     Schindler's List
# ...                                                  ...
# 52456  Sex at the Margins: Migration, Labour Markets ...
# 52458                                    Mission to Asia
# 52459  The Last Three Minutes: Conjectures About The ...
# 52464                                          Algedonic
# 52469  Heal Your Body: The Mental Causes for Physical...
#
#                            series                                  author  \
# 86               Frank McCourt #1                           Frank McCourt
# 122                           NaN          Mitch Albom (Goodreads Author)
# 129                           NaN                           Truman Capote
# 158                           NaN    Elizabeth Gilbert (Goodreads Author)
# 207                           NaN                         Thomas Keneally
# ...                           ...                                     ...
# 52456                         NaN  Laura María Agustín (Goodreads Author)
# 52458                         NaN                Christopher Henry Dawson
# 52459  The Science Masters Series                             Paul Davies
# 52464                         NaN             R.H. Sin (Goodreads Author)
# 52469                         NaN                           Louise L. Hay
#
#        rating                                        description language  \
# 86       4.11  Imbued on every page with Frank McCourt's asto...  English
# 122      4.11  Maybe it was a grandparent, or a teacher or a ...  English
# 129      4.07  On November 15, 1959, in the small town of Hol...  English
# 158      3.57  A celebrated writer's irresistible, candid, an...  English
# 207      4.34  In the shadow of Auschwitz, a flamboyant Germa...  English
# ...       ...                                                ...      ...
# 52456    4.11  This groundbreaking work explodes several myth...  English
# 52458    3.65  The narratives by John of Plano Carpini and Wi...  English
# 52459    3.81  Ragnarok. Armageddon. Doomsday. Since the dawn...  English
# 52464    3.71  Bestselling poet r.h. Sin, author of the Whisk...      NaN
# 52469    4.36  Heal Your Body is a fresh and easy step-by-ste...  English
#
#                 isbn                                             genres  \
# 86     9780007205233  ['Nonfiction', 'Memoir', 'Biography', 'Classic...
# 122    9780751529814  ['Nonfiction', 'Memoir', 'Biography', 'Inspira...
# 129    9780679745587  ['Nonfiction', 'Classics', 'True Crime', 'Crim...
# 158    9780143038412  ['Nonfiction', 'Memoir', 'Travel', 'Biography'...
# 207    9780340606513  ['History', 'Nonfiction', 'Classics', 'Holocau...
# ...              ...                                                ...
# 52456  9781842778609  ['Sex Work', 'Nonfiction', 'Feminism', 'Sociol...
# 52458  9780802064363  ['History', 'Medieval', 'Nonfiction', 'College...
# 52459  9780465038510  ['Science', 'Physics', 'Nonfiction', 'Philosop...
# 52464  9781449494223    ['Poetry', 'Nonfiction', 'Romance', 'Feminism']
# 52469  9780937611357  ['Self Help', 'Health', 'Nonfiction', 'Spiritu...
#
#                                               characters  ...  \
# 86                                     ['Frank McCourt']  ...
# 122                   ['Mitch Albom', 'Morrie Schwartz']  ...
# 129    ['Perry Edward Smith', 'Richard Hickock', 'Her...  ...
# 158    ['Liz Gilbert', 'Felipe', 'Richard from Texas'...  ...
# 207             ['Oskar Schindler', 'Amon Leopold Göth']  ...
# ...                                                  ...  ...
# 52456                                                 []  ...
# 52458                                                 []  ...
# 52459                                                 []  ...
# 52464                                                 []  ...
# 52469                                                 []  ...
#
#       firstPublishDate                                             awards  \
# 86            09/05/96  ['Pulitzer Prize for Biography or Autobiograph...
# 122           10/28/97                                                 []
# 129           10/28/65         ['Edgar Award for Best Fact Crime (1966)']
# 158           02/16/06             ['Puddly Award for Nonfiction (2008)']
# 207           10/18/82  ['Booker Prize (1982)', 'Los Angeles Times Boo...
# ...                ...                                                ...
# 52456              NaN                                                 []
# 52458             1966                                                 []
# 52459             1994                                                 []
# 52464              NaN                                                 []
# 52469     May 1st 1976                                                 []
#
#       numRatings                                     ratingsByStars  \
# 86        539576    ['224972', '193782', '88173', '22464', '10185']
# 122       782188   ['342080', '254400', '133155', '37592', '14961']
# 129       529229    ['213888', '189463', '88958', '22917', '14003']
# 158      1474731  ['411702', '410861', '368837', '170758', '1125...
# 207       144236        ['77715', '45463', '15893', '3204', '1961']
# ...          ...                                                ...
# 52456        183                       ['72', '73', '29', '5', '4']
# 52458         62                       ['13', '21', '21', '7', '0']
# 52459        920                  ['251', '329', '266', '62', '12']
# 52464       1489                ['501', '402', '339', '144', '103']
# 52469      14868             ['8640', '3745', '1864', '418', '201']
#
#       likedPercent                                            setting  \
# 86            94.0  ['Limerick (Ireland)', 'New York State (United...
# 122           93.0                                                 []
# 129           93.0                ['Holcomb, Kansas (United States)']
# 158           81.0             ['Italy', 'India', 'Bali (Indonesia)']
# 207           96.0                       ['Krakow (Kraków) (Poland)']
# ...            ...                                                ...
# 52456         95.0                                                 []
# 52458         89.0                                                 []
# 52459         92.0                                                 []
# 52464         83.0                                                 []
# 52469         96.0                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 86     https://i.gr-assets.com/images/S/compressed.ph...    290485     3242
# 122    https://i.gr-assets.com/images/S/compressed.ph...    135685     1553
# 129    https://i.gr-assets.com/images/S/compressed.ph...    125917     1494
# 158    https://i.gr-assets.com/images/S/compressed.ph...     97131     1123
# 207    https://i.gr-assets.com/images/S/compressed.ph...     67007      883
# ...                                                  ...       ...      ...
# 52456  https://i.gr-assets.com/images/S/compressed.ph...         1        1
# 52458  https://i.gr-assets.com/images/S/compressed.ph...         1        1
# 52459  https://i.gr-assets.com/images/S/compressed.ph...         1        1
# 52464  https://i.gr-assets.com/images/S/compressed.ph...         1        1
# 52469  https://i.gr-assets.com/images/S/compressed.ph...         1        1
#
#        price
# 86      2.76
# 122     3.27
# 129     6.58
# 158     2.86
# 207     0.85
# ...      ...
# 52456  13.35
# 52458   4.99
# 52459   2.53
# 52464   8.94
# 52469   4.56
#
# [8251 rows x 25 columns]

# %%
BBE_Non_NF = BBE[BBE['genres'].str.contains('Nonfiction') == False]

# %%
BBE_Non_NF
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son                    NaN
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      9999999999999  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...              ...                                                ...
# 52473  2940012616562  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...
# 52474  9999999999999                         ['Mystery', 'Young Adult']
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  ...  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...
# ...                                                  ...  ...
# 52473                                                 []  ...
# 52474                                                 []  ...
# 52475                                                 []  ...
# 52476                                                 []  ...
# 52477                                                 []  ...
#
#       firstPublishDate                                             awards  \
# 0                  NaN  ['Locus Award Nominee for Best Young Adult Boo...
# 1             06/21/03  ['Bram Stoker Award for Works for Young Reader...
# 2             07/11/60  ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 3             01/28/13                                                 []
# 4             10/05/05  ['Georgia Peach Book Award (2007)', 'Buxtehude...
# ...                ...                                                ...
# 52473              NaN                                                 []
# 52474  August 3rd 2011                                                 []
# 52475  March 15th 2011            ["Readers' Favorite Book Award (2011)"]
# 52476   April 5th 2011                                                 []
# 52477              NaN                                                 []
#
#       numRatings                                     ratingsByStars  \
# 0        6376780  ['3444695', '1921313', '745221', '171994', '93...
# 1        2507623  ['1593642', '637516', '222366', '39573', '14526']
# 2        4501075  ['2363896', '1333153', '573280', '149952', '80...
# 3        2998241  ['1617567', '816659', '373311', '113934', '767...
# 4        4964519  ['1751460', '1113682', '1008686', '542017', '5...
# ...          ...                                                ...
# 52473        871                  ['311', '310', '197', '42', '11']
# 52474         37                        ['16', '14', '5', '2', '0']
# 52475       6674             ['2109', '1868', '1660', '647', '390']
# 52476        238                      ['77', '78', '59', '19', '5']
# 52477        246                     ['106', '73', '42', '17', '8']
#
#       likedPercent                                            setting  \
# 0             96.0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1             98.0  ['Hogwarts School of Witchcraft and Wizardry (...
# 2             95.0               ['Maycomb, Alabama (United States)']
# 3             94.0  ['United Kingdom', 'Derbyshire, England (Unite...
# 4             78.0  ['Forks, Washington (United States)', 'Phoenix...
# ...            ...                                                ...
# 52473         94.0                                                 []
# 52474         95.0                                                 []
# 52475         84.0                                                 []
# 52476         90.0                                                 []
# 52477         90.0                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516
# 1      https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923
# 2      https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328
# 3      https://i.gr-assets.com/images/S/compressed.ph...   1983116    20452
# 4      https://i.gr-assets.com/images/S/compressed.ph...   1459448    14874
# ...                                                  ...       ...      ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...         0        1
#
#        price
# 0       5.09
# 1       7.38
# 2        NaN
# 3        NaN
# 4        2.1
# ...      ...
# 52473    NaN
# 52474    NaN
# 52475   7.37
# 52476   2.86
# 52477   5.20
#
# [44227 rows x 25 columns]

# %%
model_data = BBE_Non_NF.dropna(subset=['description'])

# %%
model_data
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son                    NaN
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      9999999999999  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...              ...                                                ...
# 52473  2940012616562  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...
# 52474  9999999999999                         ['Mystery', 'Young Adult']
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  ...  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...
# ...                                                  ...  ...
# 52473                                                 []  ...
# 52474                                                 []  ...
# 52475                                                 []  ...
# 52476                                                 []  ...
# 52477                                                 []  ...
#
#       firstPublishDate                                             awards  \
# 0                  NaN  ['Locus Award Nominee for Best Young Adult Boo...
# 1             06/21/03  ['Bram Stoker Award for Works for Young Reader...
# 2             07/11/60  ['Pulitzer Prize for Fiction (1961)', 'Audie A...
# 3             01/28/13                                                 []
# 4             10/05/05  ['Georgia Peach Book Award (2007)', 'Buxtehude...
# ...                ...                                                ...
# 52473              NaN                                                 []
# 52474  August 3rd 2011                                                 []
# 52475  March 15th 2011            ["Readers' Favorite Book Award (2011)"]
# 52476   April 5th 2011                                                 []
# 52477              NaN                                                 []
#
#       numRatings                                     ratingsByStars  \
# 0        6376780  ['3444695', '1921313', '745221', '171994', '93...
# 1        2507623  ['1593642', '637516', '222366', '39573', '14526']
# 2        4501075  ['2363896', '1333153', '573280', '149952', '80...
# 3        2998241  ['1617567', '816659', '373311', '113934', '767...
# 4        4964519  ['1751460', '1113682', '1008686', '542017', '5...
# ...          ...                                                ...
# 52473        871                  ['311', '310', '197', '42', '11']
# 52474         37                        ['16', '14', '5', '2', '0']
# 52475       6674             ['2109', '1868', '1660', '647', '390']
# 52476        238                      ['77', '78', '59', '19', '5']
# 52477        246                     ['106', '73', '42', '17', '8']
#
#       likedPercent                                            setting  \
# 0             96.0  ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1             98.0  ['Hogwarts School of Witchcraft and Wizardry (...
# 2             95.0               ['Maycomb, Alabama (United States)']
# 3             94.0  ['United Kingdom', 'Derbyshire, England (Unite...
# 4             78.0  ['Forks, Washington (United States)', 'Phoenix...
# ...            ...                                                ...
# 52473         94.0                                                 []
# 52474         95.0                                                 []
# 52475         84.0                                                 []
# 52476         90.0                                                 []
# 52477         90.0                                                 []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...   2993816    30516
# 1      https://i.gr-assets.com/images/S/compressed.ph...   2632233    26923
# 2      https://i.gr-assets.com/images/S/compressed.ph...   2269402    23328
# 3      https://i.gr-assets.com/images/S/compressed.ph...   1983116    20452
# 4      https://i.gr-assets.com/images/S/compressed.ph...   1459448    14874
# ...                                                  ...       ...      ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...         0        1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...         0        1
#
#        price
# 0       5.09
# 1       7.38
# 2        NaN
# 3        NaN
# 4        2.1
# ...      ...
# 52473    NaN
# 52474    NaN
# 52475   7.37
# 52476   2.86
# 52477   5.20
#
# [43019 rows x 25 columns]

# %% [markdown]
# Things to do:
# 1. Combine both datasets - lower title, remove spaces, remove duplicates
# 2. Run modeling
# 3. data architecture for ingesting data from ISBN DB
# 4. EDA
# 5. Description field clean up?

# %% [markdown]
# ##Modeling - Synonym and Library Extraction
# https://www.analyticsvidhya.com/blog/2022/03/keyword-extraction-methods-from-documents-in-nlp/
#
# 1. Select life events and create library of words for life events. Generate synonyms and similar words and phrases for life events
#
# 2. Extract key words from descriptions and calculate similarity score between library and key words.
#
# 3. Determine similarity thresholds/rules for classification for life events.

# %% [markdown]
# ##RAKE

# %%
pip install 'rake-nltk'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.7/dist-packages (from rake-nltk) (3.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.64.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2022.6.2)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from rake_nltk import Rake
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #Example

# %%
r = Rake()
my_text = """
When it comes to evaluating the performance of keyword extractors, you can use some of the standard metrics in machine learning: accuracy, precision, recall, and F1 score. However, these metrics don’t reflect partial matches; they only consider the perfect match between an extracted segment and the correct prediction for that tag.
Fortunately, there are some other metrics capable of capturing partial matches. An example of this is ROUGE.
"""
r.extract_keywords_from_text(my_text)
keywordList = []
rankedList = r.get_ranked_phrases_with_scores()
for keyword in rankedList:
  keyword_updated = keyword[1].split()
  keyword_updated_string = " ".join(keyword_updated[:2])
  keywordList.append(keyword_updated_string)
  if(len(keywordList)>9):
    break
print(keywordList)
# Out:
# ['reflect partial', 'capturing partial', 'perfect match', 'machine learning', 'keyword extractors', 'f1 score', 'extracted segment', 'correct prediction', 'standard metrics', 'metrics capable']

# %%
model_data['description']
# Out:
# 0        WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1        There is a door at the end of a silent corrido...
# 2        The unforgettable novel of a childhood in a sl...
# 3        Alternate cover edition of ISBN 9780679783268S...
# 4        About three things I was absolutely positive.\...
#                                ...
# 52473    The Fateful Trilogy continues with Fractured. ...
# 52474    'Anasazi', sequel to 'The Thirteenth Chime' by...
# 52475    --READERS FAVORITE AWARDS WINNER 2011--Sixteen...
# 52476    A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...
# 52477    Fighting in Helaman's army is Keturah's deepes...
# Name: description, Length: 43019, dtype: object

# %%
r = Rake()
keyword_col = []
for d in model_data['description']:
  my_text = d
  r.extract_keywords_from_text(my_text)
  keywordList = []
  rankedList = r.get_ranked_phrases_with_scores()
  for keyword in rankedList:
    keyword_updated = keyword[1].split()
    keyword_updated_string = " ".join(keyword_updated[:2])
    keywordList.append(keyword_updated_string)
    if(len(keywordList)>9):
      break
  keyword_col.append(keywordList)
model_data['RAKE'] = keyword_col
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
wn = nltk.WordNetLemmatizer()
for ss in wn.synsets('small'):
    print(ss.name(), ss.lemma_names())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b7f23ca2ec5a> in <module>()
#       1 wn = nltk.WordNetLemmatizer()
# ----> 2 for ss in wn.synsets('small'):
#       3     print(ss.name(), ss.lemma_names())
#
# AttributeError: 'WordNetLemmatizer' object has no attribute 'synsets'

# %%
model_data
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son                    NaN
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      9999999999999  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...              ...                                                ...
# 52473  2940012616562  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...
# 52474  9999999999999                         ['Mystery', 'Young Adult']
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  ... numRatings  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...    6376780
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...    2507623
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...    4501075
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...    2998241
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...    4964519
# ...                                                  ...  ...        ...
# 52473                                                 []  ...        871
# 52474                                                 []  ...         37
# 52475                                                 []  ...       6674
# 52476                                                 []  ...        238
# 52477                                                 []  ...        246
#
#                                           ratingsByStars likedPercent  \
# 0      ['3444695', '1921313', '745221', '171994', '93...         96.0
# 1      ['1593642', '637516', '222366', '39573', '14526']         98.0
# 2      ['2363896', '1333153', '573280', '149952', '80...         95.0
# 3      ['1617567', '816659', '373311', '113934', '767...         94.0
# 4      ['1751460', '1113682', '1008686', '542017', '5...         78.0
# ...                                                  ...          ...
# 52473                  ['311', '310', '197', '42', '11']         94.0
# 52474                        ['16', '14', '5', '2', '0']         95.0
# 52475             ['2109', '1868', '1660', '647', '390']         84.0
# 52476                      ['77', '78', '59', '19', '5']         90.0
# 52477                     ['106', '73', '42', '17', '8']         90.0
#
#                                                  setting  \
# 0      ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1      ['Hogwarts School of Witchcraft and Wizardry (...
# 2                   ['Maycomb, Alabama (United States)']
# 3      ['United Kingdom', 'Derbyshire, England (Unite...
# 4      ['Forks, Washington (United States)', 'Phoenix...
# ...                                                  ...
# 52473                                                 []
# 52474                                                 []
# 52475                                                 []
# 52476                                                 []
# 52477                                                 []
#
#                                                 coverImg bbeScore bbeVotes  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...  2993816    30516
# 1      https://i.gr-assets.com/images/S/compressed.ph...  2632233    26923
# 2      https://i.gr-assets.com/images/S/compressed.ph...  2269402    23328
# 3      https://i.gr-assets.com/images/S/compressed.ph...  1983116    20452
# 4      https://i.gr-assets.com/images/S/compressed.ph...  1459448    14874
# ...                                                  ...      ...      ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...        0        1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...        0        1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...        0        1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...        0        1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...        0        1
#
#        price                                 keywords extracted  \
# 0       5.09  [old katniss, losing means, winning means, wit...
# 1       7.38  [personality like, ordinary wizarding, hauntin...
# 2        NaN  [young alabama, harper lee, sleepy southern, 1...
# 3        NaN  [radiant wit, alternate cover, jane austen, ja...
# 4        2.1  [three things, extraordinarily suspenseful, de...
# ...      ...                                                ...
# 52473    NaN  [civil war, romantic fairytale, fateful trilog...
# 52474    NaN  [one year, anasazi ',, town claim, thirteenth ...
# 52475   7.37  [-- readers, old kara, suddenly turned, strang...
# 52476   2.86  [amanda must, fortified observatory, discover ...
# 52477   5.20  [lamanite raiders, keturah must, ranks turns, ...
#
#                                                     RAKE
# 0      [old katniss, losing means, winning means, wit...
# 1      [personality like, ordinary wizarding, hauntin...
# 2      [young alabama, harper lee, sleepy southern, 1...
# 3      [radiant wit, alternate cover, jane austen, ja...
# 4      [three things, extraordinarily suspenseful, de...
# ...                                                  ...
# 52473  [civil war, romantic fairytale, fateful trilog...
# 52474  [one year, anasazi ',, town claim, thirteenth ...
# 52475  [-- readers, old kara, suddenly turned, strang...
# 52476  [amanda must, fortified observatory, discover ...
# 52477  [lamanite raiders, keturah must, ranks turns, ...
#
# [43019 rows x 27 columns]

# %% [markdown]
# ##SPACY

# %%
pip install 'spacy'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: spacy in /usr/local/lib/python3.7/dist-packages (3.3.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (21.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.9.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: typing-extensions<4.2.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.1.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.11.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.21.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in /usr/local/lib/python3.7/dist-packages (from spacy) (8.0.17)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy) (1.8.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy) (3.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.7.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (4.64.0)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy) (0.6.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.4.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy) (57.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy) (2.23.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.6->spacy) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy) (2.0.1)

# %%
import spacy
from collections import Counter
from string import punctuation
nlp = spacy.load("en_core_web_sm")

def get_hotwords(text):
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN'] 
    doc = nlp(text.lower()) 
    for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if(token.pos_ in pos_tag):
            result.append(token.text)
    return result

keywords_spacy_list = []
for d in model_data['description']:
  output = set(get_hotwords(d))
  most_common_list = Counter(output).most_common(10)
  keywords_spacy_list.append(most_common_list)

model_data['SPACY'] = keywords_spacy_list
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-ca2375cae690> in <module>()
#      17 keywords_spacy_list = []
#      18 for d in model_data['description']:
# ---> 19   output = set(get_hotwords(d))
#      20   most_common_list = Counter(output).most_common(10)
#      21   keywords_spacy_list.append(most_common_list)
#
# <ipython-input-33-ca2375cae690> in get_hotwords(text)
#       7     result = []
#       8     pos_tag = ['PROPN', 'ADJ', 'NOUN']
# ----> 9     doc = nlp(text.lower())
#      10     for token in doc:
#      11         if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
#
# /usr/local/lib/python3.7/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#    1018                 error_handler = proc.get_error_handler()
#    1019             try:
# -> 1020                 doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1021             except KeyError as e:
#    1022                 # This typically happens if a component is not initialized
#
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/trainable_pipe.pyx in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# /usr/local/lib/python3.7/dist-packages/spacy/pipeline/tok2vec.py in predict(self, docs)
#     123             width = self.model.get_dim("nO")
#     124             return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 125         tokvecs = self.model.predict(docs)
#     126         batch_id = Tok2VecListener.get_batch_id(docs)
#     127         for listener in self.listeners:
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in predict(self, X)
#     313         only the output, instead of the `(output, callback)` tuple.
#     314         """
# --> 315         return self._func(self, X, is_train=False)[0]
#     316
#     317     def finish_update(self, optimizer: Optimizer) -> None:
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/with_array.py in forward(model, Xseq, is_train)
#      38         return model.layers[0](Xseq, is_train)
#      39     else:
# ---> 40         return _list_forward(cast(Model[List2d, List2d], model), Xseq, is_train)
#      41
#      42
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/with_array.py in _list_forward(model, Xs, is_train)
#      73     lengths = layer.ops.asarray1i([len(seq) for seq in Xs])
#      74     Xf = layer.ops.flatten(Xs, pad=pad)  # type: ignore
# ---> 75     Yf, get_dXf = layer(Xf, is_train)
#      76
#      77     def backprop(dYs: List2d) -> List2d:
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/residual.py in forward(model, X, is_train)
#      38             return d_output + dX
#      39
# ---> 40     Y, backprop_layer = model.layers[0](X, is_train)
#      41     if isinstance(X, list):
#      42         return [X[i] + Y[i] for i in range(len(X))], backprop
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/chain.py in forward(model, X, is_train)
#      52     callbacks = []
#      53     for layer in model.layers:
# ---> 54         Y, inc_layer_grad = layer(X, is_train=is_train)
#      55         callbacks.append(inc_layer_grad)
#      56         X = Y
#
# /usr/local/lib/python3.7/dist-packages/thinc/model.py in __call__(self, X, is_train)
#     289         """Call the model's `forward` function, returning the output and a
#     290         callback to compute the gradients via backpropagation."""
# --> 291         return self._func(self, X, is_train=is_train)
#     292
#     293     def initialize(self, X: Optional[InT] = None, Y: Optional[OutT] = None) -> "Model":
#
# /usr/local/lib/python3.7/dist-packages/thinc/layers/maxout.py in forward(model, X, is_train)
#      47     W = model.get_param("W")
#      48     W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 49     Y = model.ops.gemm(X, W, trans2=True)
#      50     Y += model.ops.reshape1f(b, nO * nP)
#      51     Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# /usr/local/lib/python3.7/dist-packages/thinc/backends/numpy_ops.pyx in thinc.backends.numpy_ops.NumpyOps.gemm()
#
# /usr/local/lib/python3.7/dist-packages/thinc/backends/ops.py in as_contig(self, data, dtype)
#     575         contiguous if that would not improve efficiency for the execution engine.
#     576         """
# --> 577         if data.flags["C_CONTIGUOUS"] and dtype in (None, data.dtype):
#     578             return data
#     579         kwargs = {"dtype": dtype} if dtype is not None else {}
#
# KeyboardInterrupt:

# %%
model_data
# Out:
#                                             bookId  \
# 0                         2767052-the-hunger-games
# 1      2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                       2657.To_Kill_a_Mockingbird
# 3                         1885.Pride_and_Prejudice
# 4                                   41865.Twilight
# ...                                            ...
# 52473                           11492014-fractured
# 52474                             11836711-anasazi
# 52475                              10815662-marked
# 52476                         11330278-wayward-son
# 52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 52473                                  Fractured             Fateful #2
# 52474                                    Anasazi      Sense of Truth #2
# 52475                                     Marked      Soul Guardians #1
# 52476                                Wayward Son                    NaN
# 52477                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  rating  \
# 0                                        Suzanne Collins    4.33
# 1              J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                             Harper Lee    4.28
# 3              Jane Austen, Anna Quindlen (Introduction)    4.26
# 4                                        Stephenie Meyer    3.60
# ...                                                  ...     ...
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
#                                              description language  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English
# 1      There is a door at the end of a silent corrido...  English
# 2      The unforgettable novel of a childhood in a sl...  English
# 3      Alternate cover edition of ISBN 9780679783268S...  English
# 4      About three things I was absolutely positive.\...  English
# ...                                                  ...      ...
# 52473  The Fateful Trilogy continues with Fractured. ...  English
# 52474  'Anasazi', sequel to 'The Thirteenth Chime' by...  English
# 52475  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 52476  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
# 52477  Fighting in Helaman's army is Keturah's deepes...  English
#
#                 isbn                                             genres  \
# 0      9780439023481  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1      9780439358071  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2      9999999999999  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3      9999999999999  ['Classics', 'Fiction', 'Romance', 'Historical...
# 4      9780316015844  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# ...              ...                                                ...
# 52473  2940012616562  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...
# 52474  9999999999999                         ['Mystery', 'Young Adult']
# 52475  9781461017097  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 52476  9781450755634  ['Fiction', 'Mystery', 'Historical Fiction', '...
# 52477  9781599554976  ['Lds Fiction', 'Historical Fiction', 'Young A...
#
#                                               characters  ... numRatings  \
# 0      ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...    6376780
# 1      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...    2507623
# 2      ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...    4501075
# 3      ['Mr. Bennet', 'Mrs. Bennet', 'Jane Bennet', '...  ...    2998241
# 4      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...    4964519
# ...                                                  ...  ...        ...
# 52473                                                 []  ...        871
# 52474                                                 []  ...         37
# 52475                                                 []  ...       6674
# 52476                                                 []  ...        238
# 52477                                                 []  ...        246
#
#                                           ratingsByStars likedPercent  \
# 0      ['3444695', '1921313', '745221', '171994', '93...         96.0
# 1      ['1593642', '637516', '222366', '39573', '14526']         98.0
# 2      ['2363896', '1333153', '573280', '149952', '80...         95.0
# 3      ['1617567', '816659', '373311', '113934', '767...         94.0
# 4      ['1751460', '1113682', '1008686', '542017', '5...         78.0
# ...                                                  ...          ...
# 52473                  ['311', '310', '197', '42', '11']         94.0
# 52474                        ['16', '14', '5', '2', '0']         95.0
# 52475             ['2109', '1868', '1660', '647', '390']         84.0
# 52476                      ['77', '78', '59', '19', '5']         90.0
# 52477                     ['106', '73', '42', '17', '8']         90.0
#
#                                                  setting  \
# 0      ['District 12, Panem', 'Capitol, Panem', 'Pane...
# 1      ['Hogwarts School of Witchcraft and Wizardry (...
# 2                   ['Maycomb, Alabama (United States)']
# 3      ['United Kingdom', 'Derbyshire, England (Unite...
# 4      ['Forks, Washington (United States)', 'Phoenix...
# ...                                                  ...
# 52473                                                 []
# 52474                                                 []
# 52475                                                 []
# 52476                                                 []
# 52477                                                 []
#
#                                                 coverImg bbeScore bbeVotes  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...  2993816    30516
# 1      https://i.gr-assets.com/images/S/compressed.ph...  2632233    26923
# 2      https://i.gr-assets.com/images/S/compressed.ph...  2269402    23328
# 3      https://i.gr-assets.com/images/S/compressed.ph...  1983116    20452
# 4      https://i.gr-assets.com/images/S/compressed.ph...  1459448    14874
# ...                                                  ...      ...      ...
# 52473  https://i.gr-assets.com/images/S/compressed.ph...        0        1
# 52474  https://i.gr-assets.com/images/S/compressed.ph...        0        1
# 52475  https://i.gr-assets.com/images/S/compressed.ph...        0        1
# 52476  https://i.gr-assets.com/images/S/compressed.ph...        0        1
# 52477  https://i.gr-assets.com/images/S/compressed.ph...        0        1
#
#        price                                 keywords extracted  \
# 0       5.09  [old katniss, losing means, winning means, wit...
# 1       7.38  [personality like, ordinary wizarding, hauntin...
# 2        NaN  [young alabama, harper lee, sleepy southern, 1...
# 3        NaN  [radiant wit, alternate cover, jane austen, ja...
# 4        2.1  [three things, extraordinarily suspenseful, de...
# ...      ...                                                ...
# 52473    NaN  [civil war, romantic fairytale, fateful trilog...
# 52474    NaN  [one year, anasazi ',, town claim, thirteenth ...
# 52475   7.37  [-- readers, old kara, suddenly turned, strang...
# 52476   2.86  [amanda must, fortified observatory, discover ...
# 52477   5.20  [lamanite raiders, keturah must, ranks turns, ...
#
#                                                     RAKE
# 0      [old katniss, losing means, winning means, wit...
# 1      [personality like, ordinary wizarding, hauntin...
# 2      [young alabama, harper lee, sleepy southern, 1...
# 3      [radiant wit, alternate cover, jane austen, ja...
# 4      [three things, extraordinarily suspenseful, de...
# ...                                                  ...
# 52473  [civil war, romantic fairytale, fateful trilog...
# 52474  [one year, anasazi ',, town claim, thirteenth ...
# 52475  [-- readers, old kara, suddenly turned, strang...
# 52476  [amanda must, fortified observatory, discover ...
# 52477  [lamanite raiders, keturah must, ranks turns, ...
#
# [43019 rows x 27 columns]

# %% [markdown]
# ##YAKE

# %%
pip install 'yake'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
#      |████████████████████████████████| 60 kB 4.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from yake) (1.21.6)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.7/dist-packages (from yake) (7.1.2)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting jellyfish
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 17.6 MB/s
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from yake) (2.6.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from yake) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from segtok->yake) (2022.6.2)
# Building wheels for collected packages: jellyfish
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=74002 sha256=029666200441d0b32b9275c9ede9805feca9d198dc611d4cb44468c00cf1786e
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built jellyfish
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-0.9.0 segtok-1.5.11 yake-0.4.8

# %%
import yake
keywords_list = []
for d in model_data['description']:
  doc = d
  kw_extractor = yake.KeywordExtractor()
  keywords = kw_extractor.extract_keywords(doc)
keywords_list.append(keywords)
model_data['YAKE'] = keywords_list
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-f47d1b82b5d9> in <module>()
#       4   doc = d
#       5   kw_extractor = yake.KeywordExtractor()
# ----> 6   keywords = kw_extractor.extract_keywords(doc)
#       7 keywords_list.append(keywords)
#       8 model_data['YAKE'] = keywords_list
#
# /usr/local/lib/python3.7/dist-packages/yake/yake.py in extract_keywords(self, text)
#      74                 toadd = True
#      75                 for (h, candResult) in resultSet:
# ---> 76                     dist = self.dedu_function(cand.unique_kw, candResult.unique_kw)
#      77                     if dist > self.dedupLim:
#      78                         toadd = False
#
# /usr/local/lib/python3.7/dist-packages/yake/yake.py in seqm(self, cand1, cand2)
#      54
#      55     def seqm(self, cand1, cand2):
# ---> 56         return Levenshtein.ratio(cand1, cand2)
#      57
#      58     def extract_keywords(self, text):
#
# /usr/local/lib/python3.7/dist-packages/yake/Levenshtein.py in ratio(seq1, seq2)
#       9     @staticmethod
#      10     def ratio(seq1, seq2):
# ---> 11         str_distance = Levenshtein.distance(seq1,seq2)
#      12         str_length = max(len(seq1),len(seq2))
#      13         return Levenshtein.__ratio(str_distance,str_length)
#
# /usr/local/lib/python3.7/dist-packages/yake/Levenshtein.py in distance(seq1, seq2)
#      35                         matrix[x-1,y] + 1,
#      36                         matrix[x-1,y-1] + 1,
# ---> 37                         matrix[x,y-1] + 1
#      38                     )
#      39         return (matrix[size_x - 1, size_y - 1])
#
# KeyboardInterrupt:

# %%
model_data
