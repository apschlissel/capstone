# %% [markdown]
# # LDA Data

# %%
import pandas as pd

# %%
df_full = pd.read_csv('shuffled_df.csv')
df_labeled = pd.read_csv('train_1000_labeled.csv')
# Out:
# /tmp/ipykernel_31381/2764004222.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_full = pd.read_csv('shuffled_df.csv')

# %%
df_labeled['description'][999]
# Out:
# "Santa Claus, my dear old friend, you are a thief, a traitor, a slanderer, a murderer, a liar, but worst of all you are a mockery of everything for which I stood. You have sung your last ho, ho, ho, for I am coming for your head. . . . I am coming to take back what is mine, to take back Yuletide . . .—from KrampusThe author and artist of The Child Thief returns with a modern fabulist tale of Krampus, the Lord of Yule and the dark enemy of Santa ClausOne Christmas Eve in a small hollow in Boone County, West Virginia, struggling songwriter Jesse Walker witnesses a strange spectacle: seven devilish figures chasing a man in a red suit toward a sleigh and eight reindeer. When the reindeer leap skyward, taking the sleigh, devil men, and Santa into the clouds, screams follow. Moments later, a large sack plummets back to earth, a magical sack that thrusts the down-on-his-luck singer into the clutches of the terrifying Yule Lord, Krampus. But the lines between good and evil become blurred as 
# ...

# %%
len(df_labeled)
# Out:
# 1000

# %%
df_labeled.head()
# Out:
#    Unnamed: 0.1  index Unnamed: 0                         bookId  \
# 0             0      0     39,822  34838660-not-part-of-the-plan
# 1             1      1     34,235   20176552-dragon-age-volume-1
# 2             2      2     27,904       124110.Dangerous_to_Know
# 3             3      3     10,515   1046450.The_Wheel_of_Fortune
# 4             4      4        935             872333.Blue_Bloods
#
#                   title                          series  \
# 0  Not Part of the Plan                    Blue Moon #4
# 1  Dragon Age, Volume 1  Dragon Age Graphic Novels #1-3
# 2     Dangerous to Know                             NaN
# 3  The Wheel of Fortune                             NaN
# 4           Blue Bloods                  Blue Bloods #1
#
#                                               author rating  \
# 0                      Lucy Score (Goodreads Author)   4.46
# 1  David Gaider, Chad Hardin (Illustrator), Antho...   4.26
# ...

# %%
LDA_train = df_full[1000:]

# %%
len(LDA_train)
# Out:
# 28652

# %%
LDA_train.head()
# Out:
#       Unnamed: 0.1  Unnamed: 0  \
# 1000          1000       28797
# 1001          1001        6612
# 1002          1002       18812
# 1003          1003        4134
# 1004          1004        4052
#
#                                                  bookId  \
# 1000  274618.The_Complete_Stories_of_Theodore_Sturge...
# 1001  14367051-city-of-bones-city-of-ashes-city-of-g...
# 1002                          35156.Clash_of_the_Titans
# 1003  45791.The_Ballad_of_the_Sad_Caf_and_Other_Stories
# 1004                                  20603820-the-will
#
#                                                   title  \
# 1000  The Complete Stories of Theodore Sturgeon, Vol...
# 1001  City of Bones / City of Ashes / City of Glass ...
# 1002                                Clash of the Titans
# 1003       The Ballad of the Sad Café and Other Stories
# 1004                                           The Will
#
#                                             series  \
# ...

# %%
LDA_test = df_labeled

# %%
LDA_test.head()
# Out:
#    Unnamed: 0.1  index Unnamed: 0                         bookId  \
# 0             0      0     39,822  34838660-not-part-of-the-plan
# 1             1      1     34,235   20176552-dragon-age-volume-1
# 2             2      2     27,904       124110.Dangerous_to_Know
# 3             3      3     10,515   1046450.The_Wheel_of_Fortune
# 4             4      4        935             872333.Blue_Bloods
#
#                   title                          series  \
# 0  Not Part of the Plan                    Blue Moon #4
# 1  Dragon Age, Volume 1  Dragon Age Graphic Novels #1-3
# 2     Dangerous to Know                             NaN
# 3  The Wheel of Fortune                             NaN
# 4           Blue Bloods                  Blue Bloods #1
#
#                                               author rating  \
# 0                      Lucy Score (Goodreads Author)   4.46
# 1  David Gaider, Chad Hardin (Illustrator), Antho...   4.26
# ...

# %%
len(LDA_test)
# Out:
# 1000

# %%
LDA_train.to_csv('LDA_train.csv')
LDA_test.to_csv('LDA_test.csv')
