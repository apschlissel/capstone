# %% [markdown]
# # Guided LDA
# https://www.kaggle.com/code/nvpsani/topic-modelling-using-guided-lda

# %%
import numpy as np
import s3fs
import boto3
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')

import re
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report

from lda import guidedlda
# Out:
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/ec2-user/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#import data
model_data = pd.read_csv('LDA_train.csv')
print('Tokenized Text DF Size:', len(model_data))
# Out:
# Tokenized Text DF Size: 28652
# /tmp/ipykernel_3029/3178102163.py:2: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   model_data = pd.read_csv('LDA_train.csv')

# %%
#sample model data
model_data = model_data.sample(frac=0.25, random_state=42)

# %%
model_data.head()
# Out:
#        Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0                       bookId  \
# 17885         18885         18885        5956    2272813.Ninth_Grade_Slays
# 10186         11186         11186       47684   659546.Promise_Not_to_Tell
# 17757         18757         18757       27861         248884.Berserk_Vol_6
# 15936         16936         16936       49756  14740588-notorious-nineteen
# 12340         13340         13340       37392            650584.Shadowdale
#
#                      title                             series  \
# 17885    Ninth Grade Slays  The Chronicles of Vladimir Tod #2
# 10186  Promise Not to Tell                                NaN
# 17757      Berserk, Vol. 6                 ベルセルク / Berserk #6
# 15936   Notorious Nineteen                 Stephanie Plum #19
# 12340           Shadowdale        Forgotten Realms: Avatar #1
#
#                                                   author  rating  \
# 17885        Heather Brewer (Goodreads Author), Z Brewer    4.14
# 10186  Jennifer McMahon (Goodreads Author), Kathleen ...    3.64
# 17757          Kentaro Miura, Duane Johnson (Translator)    4.56
# 15936                 Janet Evanovich (Goodreads Author)    3.94
# 12340  Scott Ciencin, Richard Awlinson (Avatar Projec...    3.71
#
#                                              description language  ...  \
# 17885  High school totally bites when you’re half hum...  English  ...
# 10186  Forty-one-year-old school nurse Kate Cypher ha...  English  ...
# 17757  Back in the day, Guts the Black Swordsman was ...  English  ...
# 15936  New Jersey bounty hunter Stephanie Plum is cer...  English  ...
# 12340  The gods walk the Realms.Banished from the hea...  English  ...
#
#        Fantasy Erotica History Dystopia Poetry Biography  Manga  Thriller  \
# 17885  Fantasy     NaN     NaN      NaN    NaN       NaN    NaN       NaN
# 10186      NaN     NaN     NaN      NaN    NaN       NaN    NaN  Thriller
# 17757  Fantasy     NaN     NaN      NaN    NaN       NaN  Manga       NaN
# 15936      NaN     NaN     NaN      NaN    NaN       NaN    NaN       NaN
# 12340  Fantasy     NaN     NaN      NaN    NaN       NaN    NaN       NaN
#
#        Graphic Novels  Romance
# 17885             NaN  Romance
# 10186             NaN      NaN
# 17757  Graphic Novels      NaN
# 15936             NaN  Romance
# 12340             NaN      NaN
#
# [5 rows x 43 columns]

# %%
#preprocessing
def preprocess_text(text):

  #lowercase text
  text_preprocessed = text.lower()
  #remove punctuation
  text_preprocessed = re.sub(r'[^a-zA-Z ]+', '', text_preprocessed)
  #tokenize for stopword removal
  text_preprocessed = word_tokenize(text_preprocessed)
  #remove stopwords
  text_preprocessed = [word for word in text_preprocessed if word not in stopwords.words('english')]
  #join to make string again
  #text_preprocessed = (" ").join(text_preprocessed)

  return text_preprocessed

# %%
# %%time
model_data['tokens'] = model_data['description'].apply(lambda x: preprocess_text(x))
# Out:
# CPU times: user 1min 13s, sys: 6.02 s, total: 1min 19s
# Wall time: 1min 19s

# %% [markdown]
# ## Synsets

# %%
def create_synsets(event):
  
  synonym = [] 
    
  for synset in wordnet.synsets(event): 
      for i in synset.lemmas(): 
          synonym.append(i.name()) # add all the synonyms available 
    
  return synonym

# %%
#creating library dataframe

#creating library dataframe


life_events = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 
               'death', 'family', 'friendship', 'marriage']

#create synsets for select events where decent synsets exist
relationship_list = create_synsets('go_steady') + ['relationship', 'kinship', 'romance', 'dating']
marriage_list = create_synsets('marriage')
wedding_list = create_synsets('wedding') + ['matrimony']

#replace underscore (_) with space
relationship_list = [i.replace("_", " ") for i in relationship_list]
marriage_list = [i.replace("_", " ") for i in marriage_list]
wedding_list = [i.replace("_", " ") for i in wedding_list]

#remove certain words
wedding_list.remove('tie')
wedding_list.remove('marriage')
relationship_list.remove('see')

synsets = [['college', 'university', 'campus', 'academia', 'professor', 'colleges', 'universities', 'professors'], 
           relationship_list, 
           ['breakup', 'break up', 'split up', 'broken up', 'dumped', 'breaks up', 'splits up', 'dumps', 'dump', 'breaks off', 'break off'], 
           ['divorce', 'divorced', 'divorces'], 
           wedding_list,  
           ['death', 'decease', 'deceased', 'dying'],
           ['family', 'mother', 'father', 'brother', 'sister', 'mom', 'dad'],
           ['friends', 'friend', 'friendship', 'friendships'],
           marriage_list]

# Create the pandas DataFrame with column name is provided explicitly
df_lib = pd.DataFrame(life_events, columns=['life_event'])
df_lib['synsets'] = synsets
 
# print dataframe.
df_lib
# Out:
#       life_event                                            synsets
# 0     university  [college, university, campus, academia, profes...
# 1  relationships  [go steady, go out, date, relationship, kinshi...
# 2      break ups  [breakup, break up, split up, broken up, dumpe...
# 3        divorce                      [divorce, divorced, divorces]
# 4        wedding  [wedding, wedding ceremony, nuptials, hymeneal...
# 5          death                  [death, decease, deceased, dying]
# 6         family  [family, mother, father, brother, sister, mom,...
# 7     friendship         [friends, friend, friendship, friendships]
# 8       marriage  [marriage, matrimony, union, spousal relations...

# %% [markdown]
# ## Guided LDA

# %%
#create objects required for model training

model_data['liststring'] = [','.join(map(str, l)) for l in model_data['tokens']]
corpus=model_data['liststring'].tolist()
vocab=list(set(word_tokenize(" ".join(model_data['liststring']))))
vectorizer = CountVectorizer(ngram_range=(1,2),vocabulary=vocab)
X = vectorizer.fit_transform(corpus)
word2id=vectorizer.vocabulary_

#synsets unigrams only

#define model
model = guidedlda.GuidedLDA(n_topics=8, n_iter=2000, random_state=7, refresh=20,alpha=0.01,eta=0.01)

synsets = [['college', 'university', 'campus', 'professor', 'professors'], 
           ['date', 'relationship', 'romance', 'dating'],
           ['breakup', 'dumped'], 
           ['divorce', 'divorced'], 
           ['wedding', 'nuptials', 'wedding', 'wedding', 'marry', 'wed', 'marry', 'wed'], 
           ['death', 'deceased', 'dying'],
           ['family', 'mother', 'father', 'brother', 'sister', 'mom', 'dad'],
           ['friends', 'friend', 'friendship', 'friendships']]

seed_topics = {}
for t_id, st in enumerate(synsets):
    for word in st:
        seed_topics[word2id[word]] = t_id

# %%
topic_num_name = {"Topic 0":"university",
                  "Topic 1":"relationships",
                  "Topic 2":"breakups",
                  "Topic 3":"divorce",
                  "Topic 4":"wedding",
                  "Topic 5": "death",
                  "Topic 6": "family",
                  "Topic 7": "friends"}

# %%
topic_list = ['universities', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']

# %%
def get_doc_topics(model_glda,X,num_topics,dataframe,col_name):
    """
    A function which creates dataframe with documents, their dominant topic, along with their probabilities
    
    Parameters
    -------------
    model_glda - Guided LDA trained model
    X - Document term frequency table
    num_topics - Number of topics the model was trained for
    dataframe - Dataframe consisting of cleaned text column
    col_name - Column name in dataframe holding cleaned text
    
    Returns
    -------------
    A dataframe with document number, topic, probability of topic
    """
    df_doc_top = pd.DataFrame()
    final_list = []
    for index in range(len(dataframe[col_name])):
        word_id_dict = dict((x,y) for x,y in zip([x for x in range(num_topics)],np.round(model.transform(X[index])*100,1).tolist()[0]))
        word_score_list = []
        for index in range(num_topics):
            try:
                value = word_id_dict[index]
            except:
                value = 0
            word_score_list.append(value)
        final_list.append(word_score_list)

    df_doc_top = pd.DataFrame(final_list)
    df_doc_top.columns = ['Topic ' + str(i) for i in range(num_topics)]
    df_doc_top.index = ['Document ' + str(i) for i in range(len(dataframe[col_name]))]

    df_doc_top["Dominant_Topic"] = df_doc_top.idxmax(axis=1).tolist()
    df_doc_top["Topic_Probability"] = df_doc_top.max(axis=1).tolist()
    #document_df = df_doc_top.reset_index().rename(columns={"index":"Document"})[["Document","Dominant_Topic","Topic_Probability"]]


    #return document_df
    return df_doc_top

# %%
model_data_test = pd.read_csv('LDA_test.csv')
model_data_test = model_data_test.replace(np.nan, False)

# %%
model_data_test['tokens'] = model_data_test['description'].apply(lambda x: preprocess_text(x))

# %%
#create test objects
#model_data_test = pd.read_csv('s3://book-data-ucb-capstone-s2022/LDA_test.csv')

#preprocess test set
#model_data_test['tokens'] = model_data_test['description'].apply(lambda x: preprocess_text(x))

#create objects required for model testing

model_data_test['liststring'] = [','.join(map(str, l)) for l in model_data_test['tokens']]
corpus=model_data_test['liststring'].tolist()
vocab=list(set(word_tokenize(" ".join(model_data_test['liststring']))))
vectorizer = CountVectorizer(ngram_range=(1,1),vocabulary=vocab)
X = vectorizer.fit_transform(corpus)
word2id=vectorizer.vocabulary_

# %% [markdown]
# ## Train Model

# %%
# %%time

alphas = [0.01, 0.1, 1]
seed_confidences = [0.05, 0.25, 0.5]

for alpha in alphas:
    for seed_confidence in seed_confidences:
        
        print('Alpha:', str(alpha), '& Seed Confidence', str(seed_confidence))
        
        #define model
        model = guidedlda.GuidedLDA(n_topics=8, n_iter=2000, random_state=7, refresh=20,alpha=alpha,eta=0.01)
        
        #fit model
        print('fitting model')
        model.fit(X, seed_topics=seed_topics, seed_confidence=seed_confidence)
        print('model fitted')
        print('')
        
        #get topics
        print('getting topics')
        document_df_test=get_doc_topics(model,X,8,model_data_test,"liststring")
        topic_list = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship', 'Dominant_Topic', 'Topic_Probability']
        document_df_test.columns = topic_list
        print('got topics')
        
        #convert preds to 
        preds = document_df_test[['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']]
        cols = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']

        #turn preds into True/False
        for col_name in cols:
            preds[col_name] =  preds[col_name] > 20
        
        #save both document_df_test and preds to csvs
        probs_csv_name = 'glda_probs_alpha_' + str(alpha) + '_seedconf_' + str(seed_confidence) + '.csv'
        bool_csv_name = 'glda_bool_alpha_' + str(alpha) + '_seedconf_' + str(seed_confidence) + '.csv'
        
        document_df_test.to_csv(probs_csv_name)
        preds.to_csv(bool_csv_name)
# Out:
# INFO:lda:n_documents: 1000
# INFO:lda:vocab_size: 18481
# INFO:lda:n_words: 77613
# INFO:lda:n_topics: 8
# INFO:lda:n_iter: 2000
# WARNING:lda:all zero column in document-term matrix found
# Alpha: 0.01 & Seed Confidence 0.05
# fitting model
# INFO:lda:<0> log likelihood: -983630
# INFO:lda:<20> log likelihood: -793124
# INFO:lda:<40> log likelihood: -784830
# INFO:lda:<60> log likelihood: -779984
# INFO:lda:<80> log likelihood: -776822
# INFO:lda:<100> log likelihood: -774058
# INFO:lda:<120> log likelihood: -772566
# INFO:lda:<140> log likelihood: -771014
# INFO:lda:<160> log likelihood: -769468
# INFO:lda:<180> log likelihood: -767916
# INFO:lda:<200> log likelihood: -766540
# INFO:lda:<220> log likelihood: -765032
# INFO:lda:<240> log likelihood: -763713
# INFO:lda:<260> log likelihood: -762564
# INFO:lda:<280> log likelihood: -761618
# INFO:lda:<300> log likelihood: -761456
# INFO:lda:<320> log likelihood: -759926
# INFO:lda:<340> log likelihood: -759209
# INFO:lda:<360> log likelihood: -758253
# INFO:lda:<380> log likelihood: -756858
# INFO:lda:<400> log likelihood: -756167
# INFO:lda:<420> log likelihood: -755659
# INFO:lda:<440> log likelihood: -754816
# INFO:lda:<460> log likelihood: -753888
# INFO:lda:<480> log likelihood: -753484
# INFO:lda:<500> log likelihood: -752740
# INFO:lda:<520> log likelihood: -752015
# INFO:lda:<540> log likelihood: -751107
# INFO:lda:<560> log likelihood: -750723
# INFO:lda:<580> log likelihood: -750290
# INFO:lda:<600> log likelihood: -749896
# INFO:lda:<620> log likelihood: -749792
# INFO:lda:<640> log likelihood: -749515
# INFO:lda:<660> log likelihood: -749094
# INFO:lda:<680> log likelihood: -748635
# INFO:lda:<700> log likelihood: -748612
# INFO:lda:<720> log likelihood: -748197
# INFO:lda:<740> log likelihood: -748470
# INFO:lda:<760> log likelihood: -747984
# INFO:lda:<780> log likelihood: -748000
# INFO:lda:<800> log likelihood: -747407
# INFO:lda:<820> log likelihood: -747127
# INFO:lda:<840> log likelihood: -747119
# INFO:lda:<860> log likelihood: -747481
# INFO:lda:<880> log likelihood: -746764
# INFO:lda:<900> log likelihood: -746971
# INFO:lda:<920> log likelihood: -746249
# INFO:lda:<940> log likelihood: -746542
# INFO:lda:<960> log likelihood: -746156
# INFO:lda:<980> log likelihood: -746420
# INFO:lda:<1000> log likelihood: -746397
# INFO:lda:<1020> log likelihood: -746077
# INFO:lda:<1040> log likelihood: -745724
# INFO:lda:<1060> log likelihood: -745421
# INFO:lda:<1080> log likelihood: -745583
# INFO:lda:<1100> log likelihood: -744993
# INFO:lda:<1120> log likelihood: -745432
# INFO:lda:<1140> log likelihood: -745426
# INFO:lda:<1160> log likelihood: -745631
# INFO:lda:<1180> log likelihood: -745508
# INFO:lda:<1200> log likelihood: -745730
# INFO:lda:<1220> log likelihood: -745758
# INFO:lda:<1240> log likelihood: -745891
# INFO:lda:<1260> log likelihood: -745483
# INFO:lda:<1280> log likelihood: -745217
# INFO:lda:<1300> log likelihood: -745023
# INFO:lda:<1320> log likelihood: -745509
# INFO:lda:<1340> log likelihood: -745845
# INFO:lda:<1360> log likelihood: -745760
# INFO:lda:<1380> log likelihood: -745858
# INFO:lda:<1400> log likelihood: -745467
# INFO:lda:<1420> log likelihood: -745463
# INFO:lda:<1440> log likelihood: -745478
# INFO:lda:<1460> log likelihood: -745408
# INFO:lda:<1480> log likelihood: -745013
# INFO:lda:<1500> log likelihood: -745328
# INFO:lda:<1520> log likelihood: -745304
# INFO:lda:<1540> log likelihood: -744732
# INFO:lda:<1560> log likelihood: -744840
# INFO:lda:<1580> log likelihood: -744771
# INFO:lda:<1600> log likelihood: -745083
# INFO:lda:<1620> log likelihood: -744836
# INFO:lda:<1640> log likelihood: -744640
# INFO:lda:<1660> log likelihood: -744466
# INFO:lda:<1680> log likelihood: -744366
# INFO:lda:<1700> log likelihood: -745047
# INFO:lda:<1720> log likelihood: -744762
# INFO:lda:<1740> log likelihood: -744525
# INFO:lda:<1760> log likelihood: -744461
# INFO:lda:<1780> log likelihood: -744814
# INFO:lda:<1800> log likelihood: -745008
# INFO:lda:<1820> log likelihood: -744427
# INFO:lda:<1840> log likelihood: -744435
# INFO:lda:<1860> log likelihood: -744299
# INFO:lda:<1880> log likelihood: -744787
# INFO:lda:<1900> log likelihood: -744783
# INFO:lda:<1920> log likelihood: -744703
# INFO:lda:<1940> log likelihood: -744310
# INFO:lda:<1960> log likelihood: -744454
# INFO:lda:<1980> log likelihood: -744388
# INFO:lda:<1999> log likelihood: -744151
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# model fitted
#
# getting topics
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# ...
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# /tmp/ipykernel_3029/3263608388.py:35: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_doc_top["Topic_Probability"] = df_doc_top.max(axis=1).tolist()
# <timed exec>:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# got topics
# CPU times: user 3min 19s, sys: 2.11 s, total: 3min 21s
# Wall time: 3min 19s

# %%
#turn prds into True/False
preds = document_df_test[['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']]
cols = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']

for col_name in cols:
    preds[col_name] =  preds[col_name] > 20

preds.head()
# Out:
# /tmp/ipykernel_3029/311618378.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   preds[col_name] =  preds[col_name] > 20
#             university  relationships  break ups  divorce  wedding  death  \
# Document 0       False          False      False    False     True  False
# Document 1       False          False      False    False    False   True
# Document 2       False           True      False    False    False  False
# Document 3       False           True      False    False     True  False
# Document 4       False          False      False    False     True  False
#
#             family  friendship
# Document 0   False        True
# Document 1    True       False
# Document 2   False       False
# Document 3   False       False
# Document 4   False        True

# %% [markdown]
# ## Seeing the model output topics and up to 10 words per topic

# %%
n_top_words = 10
topic_word = model.topic_word_
for i, topic_dist in enumerate(topic_word):
    topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words+1):-1]
    print('Topic {}: {}'.format(i, ' '.join(topic_words)))
# Out:
# Topic 0: years murder one found truth killer another past house dead
# Topic 1: love life family lives woman young mother heart man story
# Topic 2: one world power war may human powerful find earth fight
# Topic 3: become american man high war one two living boys much
# Topic 4: new author york times bestselling home set tale secret yet
# Topic 5: must world find dark city magic save battle evil adventure
# Topic 6: story book one first novel stories series readers time books
# Topic 7: life shes like never knows hes even one get new

# %% [markdown]
# ## Assigning the Topics

# %%
topic_num_name = {"Topic 0":"university",
                  "Topic 1":"relationships",
                  "Topic 2":"breakups",
                  "Topic 3":"divorce",
                  "Topic 4":"wedding",
                  "Topic 5": "death",
                  "Topic 6": "family",
                  "Topic 7": "friends"}

# %%
def get_doc_topics(model_glda,X,num_topics,dataframe,col_name):
    """
    A function which creates dataframe with documents, their dominant topic, along with their probabilities
    
    Parameters
    -------------
    model_glda - Guided LDA trained model
    X - Document term frequency table
    num_topics - Number of topics the model was trained for
    dataframe - Dataframe consisting of cleaned text column
    col_name - Column name in dataframe holding cleaned text
    
    Returns
    -------------
    A dataframe with document number, topic, probability of topic
    """
    df_doc_top = pd.DataFrame()
    final_list = []
    for index in range(len(dataframe[col_name])):
        word_id_dict = dict((x,y) for x,y in zip([x for x in range(num_topics)],np.round(model.transform(X[index])*100,1).tolist()[0]))
        word_score_list = []
        for index in range(num_topics):
            try:
                value = word_id_dict[index]
            except:
                value = 0
            word_score_list.append(value)
        final_list.append(word_score_list)

    df_doc_top = pd.DataFrame(final_list)
    df_doc_top.columns = ['Topic ' + str(i) for i in range(num_topics)]
    df_doc_top.index = ['Document ' + str(i) for i in range(len(dataframe[col_name]))]

    df_doc_top["Dominant_Topic"] = df_doc_top.idxmax(axis=1).tolist()
    df_doc_top["Topic_Probability"] = df_doc_top.max(axis=1).tolist()
    #document_df = df_doc_top.reset_index().rename(columns={"index":"Document"})[["Document","Dominant_Topic","Topic_Probability"]]


    #return document_df
    return df_doc_top

# %%
X.shape
# Out:
# (1000, 18481)

# %%
# %%time

#ignore warning
import warnings
warnings.filterwarnings("ignore")

document_df=get_doc_topics(model,X,8,model_data,"liststring")
# Out:
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:5, in <module>
#
# Input In [20], in get_doc_topics(model_glda, X, num_topics, dataframe, col_name)
#      18 final_list = []
#      19 for index in range(len(dataframe[col_name])):
# ---> 20     word_id_dict = dict((x,y) for x,y in zip([x for x in range(num_topics)],np.round(model.transform(X[index])*100,1).tolist()[0]))
#      21     word_score_list = []
#      22     for index in range(num_topics):
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/sparse/_index.py:33, in IndexMixin.__getitem__(self, key)
#      32 def __getitem__(self, key):
# ---> 33     row, col = self._validate_indices(key)
#      34     # Dispatch to specialized methods.
#      35     if isinstance(row, INT_TYPES):
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/sparse/_index.py:134, in IndexMixin._validate_indices(self, key)
#     132 row = int(row)
#     133 if row < -M or row >= M:
# --> 134     raise IndexError('row index (%d) out of range' % row)
#     135 if row < 0:
#     136     row += M
#
# IndexError: row index (1000) out of range

# %%
document_df['description']= model_data['description']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 document_df['description']= model_data['description']
#
# NameError: name 'document_df' is not defined

# %%
#output in dictionary format for each row in df
    #key: topic; value: prob
document_df

# %%
document_df.Dominant_Topic.value_counts()

# %% [markdown]
# ## Run the Test Set

# %%
#import test set

#import data
model_data_test = pd.read_csv('LDA_test.csv')
model_data_test = model_data_test.replace(np.nan, False)

print('Tokenized Text DF Size:', len(model_data_test))
# Out:
# Tokenized Text DF Size: 1000

# %%
model_data_test.columns
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'index', 'Unnamed: 0', 'bookId',
#        'title', 'series', 'author', 'rating', 'description', 'language',
#        'isbn', 'genres', 'characters', 'bookFormat', 'edition', 'pages',
#        'publisher', 'publishDate', 'firstPublishDate', 'awards', 'numRatings',
#        'ratingsByStars', 'likedPercent', 'setting', 'coverImg', 'bbeScore',
#        'bbeVotes', 'price', 'Fiction', 'Nonfiction', 'Young Adult',
#        'Childrens', 'New Adult', 'Fantasy', 'Erotica', 'History', 'Dystopia',
#        'Poetry', 'Biography', 'Manga', 'Thriller', 'Graphic Novels', 'Romance',
#        'university', 'relationships', 'break ups', 'divorce', 'weddings',
#        'death', 'family', 'friendship', 'labeled? ', 'Contains True?'],
#       dtype='object')

# %%
# %%time
model_data_test['tokens'] = model_data_test['description'].apply(lambda x: preprocess_text(x))

#create objects required for model training

model_data_test['liststring'] = [','.join(map(str, l)) for l in model_data_test['tokens']]
corpus=model_data_test['liststring'].tolist()
vocab=list(set(word_tokenize(" ".join(model_data_test['liststring']))))
vectorizer = CountVectorizer(ngram_range=(1,2),vocabulary=vocab)
X = vectorizer.fit_transform(corpus)
word2id=vectorizer.vocabulary_
# Out:
# CPU times: user 10.6 s, sys: 854 ms, total: 11.5 s
# Wall time: 11.5 s

# %%
#synsets unigrams only

topic_list = ['universities', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']

synsets = [['college', 'university', 'campus', 'professor', 'professors'], 
           ['date', 'relationship', 'romance', 'dating'],
           ['breakup', 'dumped', 'dump'], 
           ['divorce', 'divorced'], 
           ['wedding', 'wedding', 'wedding', 'marry', 'wed', 'marry', 'wed'], 
           ['death', 'deceased', 'dying'],
           ['family', 'mother', 'father', 'brother', 'sister', 'mom', 'dad'],
           ['friends', 'friend', 'friendship', 'friendships']]


seed_topics = {}
for t_id, st in enumerate(synsets):
    for word in st:
        seed_topics[word2id[word]] = t_id

# %%
document_df_test=get_doc_topics(model,X,8,model_data_test,"liststring")
# Out:
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found

# %%
cols = ['university', 'relationships', 'break ups', 'divorce', 'weddings', 'death', 'family', 'friendship']
for col_name in cols:
    model_data_test[col_name] =  model_data_test[col_name].fillna(False)

model_data_test.columns = ['Unnamed: 0.2', 'Unnamed: 0.1', 'index', 'Unnamed: 0', 'bookId',
       'title', 'series', 'author', 'rating', 'description', 'language',
       'isbn', 'genres', 'characters', 'bookFormat', 'edition', 'pages',
       'publisher', 'publishDate', 'firstPublishDate', 'awards', 'numRatings',
       'ratingsByStars', 'likedPercent', 'setting', 'coverImg', 'bbeScore',
       'bbeVotes', 'price', 'Fiction', 'Nonfiction', 'Young Adult',
       'Childrens', 'New Adult', 'Fantasy', 'Erotica', 'History', 'Dystopia',
       'Poetry', 'Biography', 'Manga', 'Thriller', 'Graphic Novels', 'Romance',
       'university', 'relationships', 'break ups', 'divorce', 'wedding',
       'death', 'family', 'friendship', 'labeled? ', 'Contains True?',
       'tokens', 'liststring']

# %%
preds.head()
# Out:
#             university  relationships  break ups  divorce  wedding  death  \
# Document 0       False          False      False    False     True  False
# Document 1       False          False      False    False    False   True
# Document 2       False           True      False    False    False  False
# Document 3       False           True      False    False     True  False
# Document 4       False          False      False    False     True  False
#
#             family  friendship
# Document 0   False        True
# Document 1    True       False
# Document 2   False       False
# Document 3   False       False
# Document 4   False        True

# %%
preds.dtypes
# Out:
# university       bool
# relationships    bool
# break ups        bool
# divorce          bool
# wedding          bool
# death            bool
# family           bool
# friendship       bool
# dtype: object

# %%
model_data_test.dtypes
# Out:
# Unnamed: 0.2          int64
# Unnamed: 0.1          int64
# index                 int64
# Unnamed: 0           object
# bookId               object
# title                object
# series               object
# author               object
# rating               object
# description          object
# language             object
# isbn                 object
# genres               object
# characters           object
# bookFormat           object
# edition              object
# pages                object
# publisher            object
# publishDate          object
# firstPublishDate     object
# awards               object
# numRatings           object
# ratingsByStars       object
# likedPercent        float64
# setting              object
# coverImg             object
# bbeScore             object
# bbeVotes             object
# price                object
# Fiction              object
# Nonfiction             bool
# Young Adult          object
# Childrens            object
# New Adult            object
# Fantasy              object
# Erotica                bool
# History              object
# Dystopia             object
# Poetry                 bool
# Biography              bool
# Manga                object
# Thriller             object
# Graphic Novels       object
# Romance              object
# university             bool
# relationships          bool
# break ups              bool
# divorce                bool
# wedding                bool
# death                  bool
# family                 bool
# friendship             bool
# labeled?             object
# Contains True?       object
# tokens               object
# liststring           object
# dtype: object

# %%
model_data_test
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  index Unnamed: 0  \
# 0               0             0      0     39,822
# 1               1             1      1     34,235
# 2               2             2      2     27,904
# 3               3             3      3     10,515
# 4               4             4      4        935
# ..            ...           ...    ...        ...
# 995           995           995    995     17,361
# 996           996           996    996      9,029
# 997           997           997    997     32,216
# 998           998           998    998      1,036
# 999           999           999    999   9,738.00
#
#                                        bookId  \
# 0               34838660-not-part-of-the-plan
# 1                20176552-dragon-age-volume-1
# 2                    124110.Dangerous_to_Know
# 3                1046450.The_Wheel_of_Fortune
# 4                          872333.Blue_Bloods
# ..                                        ...
# 995                    588326.The_Blue_Helmet
# 996  93007.The_Merry_Adventures_of_Robin_Hood
# 997                  1085376.Before_You_Sleep
# 998                            28195.Inkspell
# 999                          13505670-krampus
#
#                                   title                          series  \
# 0                  Not Part of the Plan                    Blue Moon #4
# 1                  Dragon Age, Volume 1  Dragon Age Graphic Novels #1-3
# 2                     Dangerous to Know                           False
# 3                  The Wheel of Fortune                           False
# 4                           Blue Bloods                  Blue Bloods #1
# ..                                  ...                             ...
# 995                     The Blue Helmet                           False
# 996  The Merry Adventures of Robin Hood                           False
# 997                    Before You Sleep                           False
# 998                            Inkspell                     Inkworld #2
# 999              Krampus: The Yule Lord                           False
#
#                                                 author rating  \
# 0                        Lucy Score (Goodreads Author)   4.46
# 1    David Gaider, Chad Hardin (Illustrator), Antho...   4.26
# 2           Barbara Taylor Bradford (Goodreads Author)   3.73
# 3                                        Susan Howatch   4.11
# 4                Melissa de la Cruz (Goodreads Author)   3.69
# ..                                                 ...    ...
# 995                                       William Bell   3.42
# 996                                        Howard Pyle   4.07
# 997          Linn Ullmann, Tiina Nunnally (Translator)   3.34
# 998  Cornelia Funke (Goodreads Author), Anthea Bell...   3.91
# 999                                               Brom  $4.08
#
#                                            description  ... break ups divorce  \
# 0    From the Wall Street Journal and #1 Amazon bes...  ...     False   False
# 1    Helping set the stage for BioWare's hotly anti...  ...     False   False
# 2    Sebastian Locke, the fifty-six-year-old patria...  ...     False    True
# 3    "Take me back to Oxmoon, the lost paradise of ...  ...     False   False
# 4    When the Mayflower set sail in 1620, it carrie...  ...     False   False
# ..                                                 ...  ...       ...     ...
# 995  Lee wants to be a Tarantula – a member of the ...  ...     False   False
# 996  The Merry Adventures of Robin Hood of Great Re...  ...     False   False
# 997  Moving from present-day Oslo to Brooklyn in th...  ...     False   False
# 998  The captivating sequel to INKHEART, the critic...  ...     False   False
# 999  Santa Claus, my dear old friend, you are a thi...  ...     False   False
#
#     wedding  death family friendship labeled?  Contains True?  \
# 0     False  False  False      False       Yes            1.0
# 1     False  False  False      False       Yes            0.0
# 2     False   True   True      False       Yes            1.0
# 3     False  False   True      False       Yes            1.0
# 4     False  False  False      False       Yes            0.0
# ..      ...    ...    ...        ...       ...            ...
# 995   False  False  False       True     False            1.0
# 996   False  False  False      False     False            0.0
# 997   False  False   True      False     False            1.0
# 998   False  False  False      False     False            0.0
# 999   False  False   True       True     False          False
#
#                                                 tokens  \
# 0    [wall, street, journal, amazon, bestselling, a...
# 1    [helping, set, stage, biowares, hotly, anticip...
# 2    [sebastian, locke, fiftysixyearold, patriarch,...
# 3    [take, back, oxmoon, lost, paradise, childhood...
# 4    [mayflower, set, sail, carried, board, men, wo...
# ..                                                 ...
# 995  [lee, wants, tarantula, member, biggest, power...
# 996  [merry, adventures, robin, hood, great, renown...
# 997  [moving, presentday, oslo, brooklyn, sleep, te...
# 998  [captivating, sequel, inkheart, critically, ac...
# 999  [santa, claus, dear, old, friend, thief, trait...
#
#                                             liststring
# 0    wall,street,journal,amazon,bestselling,author,...
# 1    helping,set,stage,biowares,hotly,anticipated,d...
# 2    sebastian,locke,fiftysixyearold,patriarch,powe...
# 3    take,back,oxmoon,lost,paradise,childhood,take,...
# 4    mayflower,set,sail,carried,board,men,women,wou...
# ..                                                 ...
# 995  lee,wants,tarantula,member,biggest,powerful,ga...
# 996  merry,adventures,robin,hood,great,renown,notti...
# 997  moving,presentday,oslo,brooklyn,sleep,tells,st...
# 998  captivating,sequel,inkheart,critically,acclaim...
# 999  santa,claus,dear,old,friend,thief,traitor,slan...
#
# [1000 rows x 56 columns]

# %% [markdown]
# ## Next Step: Chart of seed_confidence to accuracy

# %%
# %%time

alphas = [0.01, 0.1, 1]
seed_confidences = [0.05, 0.25, 0.5]

results = {}

for alpha in alphas:
    for seed_confidence in seed_confidences:
        
        print('Alpha:', str(alpha), '& Seed Confidence', str(seed_confidence))
        
        #define model
        model = guidedlda.GuidedLDA(n_topics=8, n_iter=2000, random_state=7, refresh=20,alpha=alpha,eta=0.01)
        
        #fit model
        print('fitting model')
        model.fit(X, seed_topics=seed_topics, seed_confidence=seed_confidence)
        print('model fitted')
        print('')
        
        #get topics
        print('getting topics')
        document_df_test=get_doc_topics(model,X,8,model_data_test,"liststring")
        topic_list = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship', 'Dominant_Topic', 'Topic_Probability']
        document_df_test.columns = topic_list
        print('got topics')
        
        #convert preds to 
        preds = document_df_test[['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']]
        print(preds.head())
        model_data_test_reduced = model_data_test[['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']]
        print(model_data_test_reduced.head())
        cols = ['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']

        #turn preds into True/False
        for col_name in cols:
            preds[col_name] =  preds[col_name] > 20
            
        #create dict key
        #key_name = 'alpha_' + str(alpha) + '_seedconf_' + str(seed_confidence)
        
        y_true = np.array(preds.values.tolist())
        y_pred = np.array(model_data_test_reduced.values.tolist())
        
        print(y_true)
        print(y_pred)

        print(classification_report(
            model_data_test_reduced,
            preds,
            #output_dict=True,
            target_names=['university', 'relationships', 'break ups', 'divorce', 'wedding', 'death', 'family', 'friendship']))
# Out:
# INFO:lda:n_documents: 1000
# INFO:lda:vocab_size: 18481
# INFO:lda:n_words: 77613
# INFO:lda:n_topics: 8
# INFO:lda:n_iter: 2000
# WARNING:lda:all zero column in document-term matrix found
# Alpha: 0.01 & Seed Confidence 0.05
# fitting model
# INFO:lda:<0> log likelihood: -983615
# INFO:lda:<20> log likelihood: -793707
# INFO:lda:<40> log likelihood: -785034
# INFO:lda:<60> log likelihood: -780247
# INFO:lda:<80> log likelihood: -776246
# INFO:lda:<100> log likelihood: -773792
# INFO:lda:<120> log likelihood: -771742
# INFO:lda:<140> log likelihood: -769756
# INFO:lda:<160> log likelihood: -767657
# INFO:lda:<180> log likelihood: -766438
# INFO:lda:<200> log likelihood: -764720
# INFO:lda:<220> log likelihood: -763855
# INFO:lda:<240> log likelihood: -763008
# INFO:lda:<260> log likelihood: -762122
# INFO:lda:<280> log likelihood: -760968
# INFO:lda:<300> log likelihood: -760605
# INFO:lda:<320> log likelihood: -759208
# INFO:lda:<340> log likelihood: -758494
# INFO:lda:<360> log likelihood: -757919
# INFO:lda:<380> log likelihood: -756862
# INFO:lda:<400> log likelihood: -756564
# INFO:lda:<420> log likelihood: -756495
# INFO:lda:<440> log likelihood: -755516
# INFO:lda:<460> log likelihood: -754917
# INFO:lda:<480> log likelihood: -755249
# INFO:lda:<500> log likelihood: -754497
# INFO:lda:<520> log likelihood: -754373
# INFO:lda:<540> log likelihood: -753146
# INFO:lda:<560> log likelihood: -753175
# INFO:lda:<580> log likelihood: -753050
# INFO:lda:<600> log likelihood: -752372
# INFO:lda:<620> log likelihood: -752434
# INFO:lda:<640> log likelihood: -751892
# INFO:lda:<660> log likelihood: -751551
# INFO:lda:<680> log likelihood: -751482
# INFO:lda:<700> log likelihood: -750959
# INFO:lda:<720> log likelihood: -750450
# INFO:lda:<740> log likelihood: -750511
# INFO:lda:<760> log likelihood: -750699
# INFO:lda:<780> log likelihood: -750092
# INFO:lda:<800> log likelihood: -749537
# INFO:lda:<820> log likelihood: -749262
# INFO:lda:<840> log likelihood: -748856
# INFO:lda:<860> log likelihood: -749042
# INFO:lda:<880> log likelihood: -748847
# INFO:lda:<900> log likelihood: -748957
# INFO:lda:<920> log likelihood: -749158
# INFO:lda:<940> log likelihood: -748967
# INFO:lda:<960> log likelihood: -748461
# INFO:lda:<980> log likelihood: -748447
# INFO:lda:<1000> log likelihood: -748119
# INFO:lda:<1020> log likelihood: -748059
# INFO:lda:<1040> log likelihood: -747688
# INFO:lda:<1060> log likelihood: -747909
# INFO:lda:<1080> log likelihood: -747631
# INFO:lda:<1100> log likelihood: -747867
# INFO:lda:<1120> log likelihood: -747305
# INFO:lda:<1140> log likelihood: -747756
# INFO:lda:<1160> log likelihood: -747853
# INFO:lda:<1180> log likelihood: -747771
# INFO:lda:<1200> log likelihood: -747145
# INFO:lda:<1220> log likelihood: -747123
# INFO:lda:<1240> log likelihood: -747226
# INFO:lda:<1260> log likelihood: -747099
# INFO:lda:<1280> log likelihood: -747601
# INFO:lda:<1300> log likelihood: -747028
# INFO:lda:<1320> log likelihood: -747241
# INFO:lda:<1340> log likelihood: -746981
# INFO:lda:<1360> log likelihood: -747126
# INFO:lda:<1380> log likelihood: -747283
# INFO:lda:<1400> log likelihood: -747058
# INFO:lda:<1420> log likelihood: -746641
# INFO:lda:<1440> log likelihood: -746774
# INFO:lda:<1460> log likelihood: -746784
# INFO:lda:<1480> log likelihood: -746836
# INFO:lda:<1500> log likelihood: -746589
# INFO:lda:<1520> log likelihood: -746632
# INFO:lda:<1540> log likelihood: -746419
# INFO:lda:<1560> log likelihood: -746387
# INFO:lda:<1580> log likelihood: -746453
# INFO:lda:<1600> log likelihood: -746216
# INFO:lda:<1620> log likelihood: -746392
# INFO:lda:<1640> log likelihood: -746474
# INFO:lda:<1660> log likelihood: -746510
# INFO:lda:<1680> log likelihood: -746449
# INFO:lda:<1700> log likelihood: -746333
# INFO:lda:<1720> log likelihood: -746602
# INFO:lda:<1740> log likelihood: -746240
# INFO:lda:<1760> log likelihood: -746051
# INFO:lda:<1780> log likelihood: -746822
# INFO:lda:<1800> log likelihood: -746099
# INFO:lda:<1820> log likelihood: -746121
# INFO:lda:<1840> log likelihood: -746643
# INFO:lda:<1860> log likelihood: -746041
# INFO:lda:<1880> log likelihood: -745982
# INFO:lda:<1900> log likelihood: -746097
# INFO:lda:<1920> log likelihood: -746159
# INFO:lda:<1940> log likelihood: -745879
# INFO:lda:<1960> log likelihood: -745994
# INFO:lda:<1980> log likelihood: -746372
# INFO:lda:<1999> log likelihood: -746069
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# model fitted
#
# getting topics
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# ...
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# WARNING:lda:all zero column in document-term matrix found
# got topics
#             university  relationships  break ups  divorce  wedding  death  \
# Document 0        10.3            0.3        5.5      7.7     14.0    0.1
# Document 1         2.1           59.6       23.1      0.3      9.6    1.4
# Document 2        36.6            4.8        2.7     13.5     13.9    5.8
# Document 3        36.3           13.7        5.6     11.0      8.6    1.6
# Document 4        30.8            3.5       15.0      1.0     25.4    5.8
#
#             family  friendship
# Document 0     5.9        56.1
# Document 1     3.7         0.2
# Document 2    16.8         6.0
# Document 3    20.6         2.6
# Document 4     1.7        16.8
#    university  relationships  break ups  divorce  wedding  death  family  \
# 0       False           True      False    False    False  False   False
# 1       False          False      False    False    False  False   False
# 2       False           True      False     True    False   True    True
# 3       False           True      False    False    False  False    True
# 4       False          False      False    False    False  False   False
#
#    friendship
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# [[False False False ... False False  True]
#  [False  True  True ... False False False]
#  [ True False False ... False False False]
#  ...
#  [False False False ... False  True False]
#  [False  True False ... False False False]
#  [False False False ...  True False False]]
# [[False  True False ... False False False]
#  [False False False ... False False False]
#  [False  True False ...  True  True False]
#  ...
#  [False False False ... False  True False]
#  [False False False ... False False False]
#  [False False False ... False  True  True]]
#                precision    recall  f1-score   support
#
#    university       0.04      0.31      0.07        26
# relationships       0.16      0.07      0.09       399
#     break ups       0.00      0.25      0.01         4
#       divorce       0.00      0.00      0.00        12
#       wedding       0.02      0.16      0.03        19
#         death       0.01      0.03      0.01        29
#        family       0.32      0.31      0.31       187
#    friendship       0.28      0.57      0.37       191
#
#     micro avg       0.12      0.24      0.16       867
#     macro avg       0.10      0.21      0.11       867
#  weighted avg       0.20      0.24      0.20       867
#   samples avg       0.12      0.13      0.12       867
#
# CPU times: user 3min 19s, sys: 2.17 s, total: 3min 22s
# Wall time: 3min 19s

# %% [markdown]
# ## Plot accuracies

# %%
#make df
alpha_dict = {'alpha': [0.01, 0.1, 1], 'macro_avg_precision': [0.07, 0.09, 0.09]}
df_alpha = pd.DataFrame(data=alpha_dict)

#plot df
df_alpha.plot.line(x='alpha', y='macro_avg_precision', ylim=(0,1), ylabel='Micro Average Precision', xlabel='Alpha', title='Micro Average Precision by Alpha', legend=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'micro_avg_precision'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [35], in <cell line: 6>()
#       3 df_alpha = pd.DataFrame(data=alpha_dict)
#       5 #plot df
# ----> 6 df_alpha.plot.line(x='alpha', y='micro_avg_precision', ylim=(0,1), ylabel='Micro Average Precision', xlabel='Alpha', title='Micro Average Precision by Alpha', legend=False)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py:1041, in PlotAccessor.line(self, x, y, **kwargs)
#     976 @Appender(
#     977     """
#     978     See Also
#    (...)
#    1033 @Appender(_bar_or_line_doc)
#    1034 def line(self, x=None, y=None, **kwargs):
#    1035     """
#    1036     Plot Series or DataFrame as lines.
#    1037
#    1038     This function is useful to plot lines using DataFrame's values
#    1039     as coordinates.
#    1040     """
# -> 1041     return self(kind="line", x=x, y=y, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/plotting/_core.py:958, in PlotAccessor.__call__(self, *args, **kwargs)
#     955             pass
#     957 # don't overwrite
# --> 958 data = data[y].copy()
#     960 if isinstance(data, ABCSeries):
#     961     label_name = label_kw or y
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'micro_avg_precision'

# %%
#make df
seed_confidence_dict = {'seed_confidence': [0.05, 0.25, 0.5], 'micro_avg_precision': [0.07, 0.08, 0.09]}
df_seed_confidence = pd.DataFrame(data=seed_confidence_dict)

#plot df
df_seed_confidence.plot.line(x='seed_confidence', y='micro_avg_precision', ylim=(0,1), ylabel='Micro Average Precision', xlabel='Seed Confidence', title='Micro Average Precision by Alpha', legend=False)
