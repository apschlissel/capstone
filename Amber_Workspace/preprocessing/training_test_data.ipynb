# %%
import pandas as pd
df = pd.read_csv('shuffled_df.csv')
# Out:
# /tmp/ipykernel_9778/2266746450.py:2: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('shuffled_df.csv')

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0                                       bookId  \
# 0                 0       39822                34838660-not-part-of-the-plan
# 1                 1       34235                 20176552-dragon-age-volume-1
# 2                 2       27904                     124110.Dangerous_to_Know
# 3                 3       10515                 1046450.The_Wheel_of_Fortune
# 4                 4         935                           872333.Blue_Bloods
# ...             ...         ...                                          ...
# 29647         29647       38855                                26162284-katy
# 29648         29648       11399                   29762106-the-anonymous-man
# 29649         29649        2239                             608287.Jesus_Son
# 29650         29650       47747  293453.Akiko_in_the_Castle_of_Alia_Rellapor
# 29651         29651        5095                         20510241-the-calling
#
# ...

# %%
train = df[0:10000]
test = df[10000:12500]

# %%
train.to_csv('train.csv')
test.to_csv('test.csv')
