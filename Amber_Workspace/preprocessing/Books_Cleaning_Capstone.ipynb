# %% [markdown]
# <a href="https://colab.research.google.com/github/apschlissel/capstone/blob/main/Books_Cleaning_Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CAPSTONE - Books Data Cleaning and Light EDA Script

# %% [markdown]
# Don't forget to load the books_expanded.csv into the google colab storage.

# %%
##Import Libraries
import numpy as np
import pandas as pd

# %%
## Read in Data
original_book_df = pd.read_csv('./books_expanded.csv', sep=',')

original_book_df.shape[0]
# Out:
# 52479

# %%
original_book_df.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %% [markdown]
# FILTER THE DATA

# %%
## Remove Blank Descriptions
filt_df = original_book_df.dropna(subset=['description'])
filt_df.shape[0]
# Out:
# 51140

# %%
## Genre Filters - Definitely
filt_df = filt_df[filt_df['Nonfiction'] != "Nonfiction"]
filt_df = filt_df[filt_df['Erotica'] != "Erotica"]
filt_df.shape[0]
# Out:
# 41012

# %%
## Additional Genre's - Added 6/29
filt_df = filt_df[~filt_df["genres"].str.contains('Parenting')]
filt_df = filt_df[~filt_df["genres"].str.contains('Picture Books')]
filt_df.shape[0]
# Out:
# 40391

# %%
## Genre Filters - Possibly
filt_df = filt_df[filt_df['Biography'] != "Biography"]
filt_df = filt_df[filt_df['Poetry'] != "Poetry"]
filt_df = filt_df[filt_df['genres'] != "[]"]
filt_df.shape[0]
# Out:
# 35232

# %%
## Language Filters
filt_df = filt_df[(filt_df['language'] == "English") | (filt_df['language'] == "")]
filt_df.shape[0]
# Out:
# 29656

# %%
## Book Format Filters
filt_df = filt_df[filt_df['bookFormat'] != "Album"] 
filt_df = filt_df[filt_df['bookFormat'] != "Wattpad"]
filt_df = filt_df[(filt_df['bookFormat'] != "Newsprint")]
filt_df = filt_df[filt_df['bookFormat'] != "Newsletter Serial"]
filt_df = filt_df[(filt_df['bookFormat'] != "Board Book") & (filt_df['bookFormat'] != "Board")]
filt_df.shape[0]
# Out:
# 29652

# %%
filt_df.tail()
# Out:
#                              bookId                title  \
# 52473            11492014-fractured            Fractured
# 52474              11836711-anasazi              Anasazi
# 52475               10815662-marked               Marked
# 52476          11330278-wayward-son          Wayward Son
# 52477  10991547-daughter-of-helaman  Daughter of Helaman
#
#                      series  \
# 52473            Fateful #2
# 52474     Sense of Truth #2
# 52475     Soul Guardians #1
# 52476                   NaN
# 52477  Stripling Warrior #1
#
#                                                   author  rating  \
# 52473                   Cheri Schmidt (Goodreads Author)    4.00
# 52474                                      Emma Michaels    4.19
# 52475                  Kim Richardson (Goodreads Author)    3.70
# 52476  Tom Pollack (Goodreads Author), John Loftus (G...    3.85
# 52477                    Misty Moncur (Goodreads Author)    4.02
#
# ...

# %%
##Write out the Filtered Dataframe to a .csv
filt_df.to_csv("./books_filtered.csv", sep=',', encoding='utf-8')

# %% [markdown]
# Reducing to Columns to Pertinent Only

# %%
##Removing Columns
reduced_df = filt_df.drop(columns=['rating', 'characters', 'awards', 'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg', 'price', 'bbeVotes', 'bbeScore'])
reduced_df = reduced_df.drop(columns=['bookFormat', 'edition', 'publisher', 'firstPublishDate', 'language'])
reduced_df = reduced_df.drop(columns=['Poetry', 'Biography', 'Erotica', 'Nonfiction'])
reduced_df.shape[0]
# Out:
# 29652

# %%
reduced_df.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# ...

# %%
reduced_df.to_csv("./books_filtered_colsreduced.csv", sep=',', encoding='utf-8')
