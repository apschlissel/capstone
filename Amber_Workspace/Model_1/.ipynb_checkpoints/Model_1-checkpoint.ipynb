# %% [markdown]
# # Model #1 Synonym & Library Extraction - Exact Match

# %%
pip install 'rake-nltk'
# Out:
# Requirement already satisfied: rake-nltk in /home/ec2-user/anaconda3/lib/python3.9/site-packages (1.0.6)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /home/ec2-user/anaconda3/lib/python3.9/site-packages (from rake-nltk) (3.7)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.64.0)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.1.0)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /home/ec2-user/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2022.3.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
import s3fs
import boto3
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')

import re
from nltk.corpus import stopwords
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/ec2-user/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ## Pull in Data From S3 Bucket

# %%
# csv file
df_books_filtered = pd.read_csv('s3://ec2-jupyter-notebook-us-west-2-8c94c42abbd5478ca9a1a477613965a7/books_filtered.csv')
model_data = pd.read_csv('s3://ec2-jupyter-notebook-us-west-2-8c94c42abbd5478ca9a1a477613965a7/books_filtered_colsreduced.csv')

# %% [markdown]
# ## Preprocessing

# %%
def preprocess_text(text):

  #lowercase text
  text_preprocessed = text.lower()
  #remove punctuation
  text_preprocessed = re.sub(r'[^a-zA-Z ]+', '', text_preprocessed)
  #tokenize for stopword removal
  text_preprocessed = word_tokenize(text_preprocessed)
  #remove stopwords
  text_preprocessed = [word for word in text_preprocessed if word not in stopwords.words('english')]
  #join to make string again
  #text_preprocessed = (" ").join(text_preprocessed)

  return set(text_preprocessed)

# %%
#model_data['tokens'] = model_data['description'].apply(lambda x: preprocess_text(x))

# %%
from rake_nltk import Rake
r = Rake()
keyword_col = []
for d in model_data['description']:
  my_text = d
  r.extract_keywords_from_text(my_text)
  keywordList = []
  rankedList = r.get_ranked_phrases_with_scores()
  for keyword in rankedList:
    keyword_updated = keyword[1].split()
    keyword_updated_string = " ".join(keyword_updated[:2])
    keywordList.append(keyword_updated_string)
    if(len(keywordList)>9):
      break
  keyword_col.append(set(keywordList))
model_data['RAKE'] = keyword_col

# %%
model_data.head()
# Out:
#    Unnamed: 0                                       bookId  \
# 0           0                     2767052-the-hunger-games
# 1           1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2           2                   2657.To_Kill_a_Mockingbird
# 3           3                     1885.Pride_and_Prejudice
# 4           4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  \
# 0                            Suzanne Collins
# 1  J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                 Harper Lee
# 3  Jane Austen, Anna Quindlen (Introduction)
# 4                            Stephenie Meyer
#
#                                          description         isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9.78044E+12
# 1  There is a door at the end of a silent corrido...  9.78044E+12
# 2  The unforgettable novel of a childhood in a sl...        1E+13
# 3  Alternate cover edition of ISBN 9780679783268S...        1E+13
# 4  About three things I was absolutely positive.\...  9.78032E+12
#
#                                               genres pages publishDate  ...  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374   9/14/2008  ...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870   9/28/2004  ...
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...   324   5/23/2006  ...
# 3  ['Classics', 'Fiction', 'Romance', 'Historical...   279  10/10/2000  ...
# 4  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501    9/6/2006  ...
#
#    Childrens New Adult  Fantasy History  Dystopia Manga Thriller  \
# 0        NaN       NaN  Fantasy     NaN  Dystopia   NaN      NaN
# 1  Childrens       NaN  Fantasy     NaN       NaN   NaN      NaN
# 2        NaN       NaN      NaN     NaN       NaN   NaN      NaN
# 3        NaN       NaN      NaN     NaN       NaN   NaN      NaN
# 4        NaN       NaN  Fantasy     NaN       NaN   NaN      NaN
#
#   Graphic Novels  Romance                                               RAKE
# 0            NaN  Romance  {old katniss, without really, shining capitol,...
# 1            NaN      NaN  {unbearable sacrifice, silent corridor, haunti...
# 2            NaN      NaN  {18 million, young alabama, winning film, slee...
# 3            NaN  Romance  {romantic clash, regency england, radiant wit,...
# 4            NaN  Romance  {deeply seductive, part might, love story, ext...
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Libraries

# %%
def create_synsets(event):
  
  synonym = [] 
    
  for synset in wordnet.synsets(event): 
      for i in synset.lemmas(): 
          synonym.append(i.name()) # add all the synonyms available 
    
  return set(synonym)

# %%
#creating library dataframe

# initialize list elements
data = ['College', 'Relationships', 'Divorce', 'Death', 'Wedding', 'Stress', 'Moving', 'Coming of age', 'Adulting']
 
# Create the pandas DataFrame with column name is provided explicitly
df_lib = pd.DataFrame(data, columns=['life_event'])
 
# print dataframe.
df_lib
# Out:
#       life_event
# 0        College
# 1  Relationships
# 2        Divorce
# 3          Death
# 4        Wedding
# 5         Stress
# 6         Moving
# 7  Coming of age
# 8       Adulting

# %%
df_lib['words'] = df_lib['life_event'].apply(lambda x: create_synsets(x))

# %%
df_lib
# Out:
#       life_event                                              words
# 0        College                                          {college}
# 1  Relationships  {family_relationship, relationship, human_rela...
# 2        Divorce  {dissociate, split_up, disunite, divorcement, ...
# 3          Death  {death, last, destruction, end, decease, Death...
# 4        Wedding  {wedding_ceremony, wedding_party, hook_up_with...
# 5         Stress  {punctuate, tenseness, accentuate, stress, ten...
# 6         Moving  {prompt, impress, motivate, move, moving, make...
# 7  Coming of age                                                 {}
# 8       Adulting                                                 {}

# %% [markdown]
# ## Match Tokens to Libraries

# %%
def library_match(model_data, library_data):
  for index, row in library_data.iterrows(): #per life event
    LE = row['life_event']
    LE_words = row['words']
    LE_list = []
    for tokens in model_data['RAKE']: #for each book 
      #find set intersection (common words)
        matches = tokens.intersection(LE_words)
        #matches = list(matches)
        LE_list.append(matches)
    model_data[LE] = LE_list

# %%
library_match(model_data, df_lib)

# %%
model_data
# Out:
#        Unnamed: 0                                       bookId  \
# 0               0                     2767052-the-hunger-games
# 1               1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2               2                   2657.To_Kill_a_Mockingbird
# 3               3                     1885.Pride_and_Prejudice
# 4               4                               41865.Twilight
# ...           ...                                          ...
# 29647       52473                           11492014-fractured
# 29648       52474                             11836711-anasazi
# 29649       52475                              10815662-marked
# 29650       52476                         11330278-wayward-son
# 29651       52477                 10991547-daughter-of-helaman
#
#                                            title                 series  \
# 0                               The Hunger Games    The Hunger Games #1
# 1      Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                          To Kill a Mockingbird  To Kill a Mockingbird
# 3                            Pride and Prejudice                    NaN
# 4                                       Twilight   The Twilight Saga #1
# ...                                          ...                    ...
# 29647                                  Fractured             Fateful #2
# 29648                                    Anasazi      Sense of Truth #2
# 29649                                     Marked      Soul Guardians #1
# 29650                                Wayward Son                    NaN
# 29651                        Daughter of Helaman   Stripling Warrior #1
#
#                                                   author  \
# 0                                        Suzanne Collins
# 1              J.K. Rowling, Mary GrandPré (Illustrator)
# 2                                             Harper Lee
# 3              Jane Austen, Anna Quindlen (Introduction)
# 4                                        Stephenie Meyer
# ...                                                  ...
# 29647                   Cheri Schmidt (Goodreads Author)
# 29648                                      Emma Michaels
# 29649                  Kim Richardson (Goodreads Author)
# 29650  Tom Pollack (Goodreads Author), John Loftus (G...
# 29651                    Misty Moncur (Goodreads Author)
#
#                                              description         isbn  \
# 0      WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  9.78044E+12
# 1      There is a door at the end of a silent corrido...  9.78044E+12
# 2      The unforgettable novel of a childhood in a sl...        1E+13
# 3      Alternate cover edition of ISBN 9780679783268S...        1E+13
# 4      About three things I was absolutely positive.\...  9.78032E+12
# ...                                                  ...          ...
# 29647  The Fateful Trilogy continues with Fractured. ...  2.94001E+12
# 29648  'Anasazi', sequel to 'The Thirteenth Chime' by...        1E+13
# 29649  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  9.78146E+12
# 29650  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  9.78145E+12
# 29651  Fighting in Helaman's army is Keturah's deepes...   9.7816E+12
#
#                                                   genres pages  \
# 0      ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...   374
# 1      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...   870
# 2      ['Classics', 'Fiction', 'Historical Fiction', ...   324
# 3      ['Classics', 'Fiction', 'Romance', 'Historical...   279
# 4      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...   501
# ...                                                  ...   ...
# 29647  ['Vampires', 'Paranormal', 'Young Adult', 'Rom...     0
# 29648                         ['Mystery', 'Young Adult']   190
# 29649  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...   280
# 29650  ['Fiction', 'Mystery', 'Historical Fiction', '...   507
# 29651  ['Lds Fiction', 'Historical Fiction', 'Young A...   201
#
#               publishDate  ...  \
# 0               9/14/2008  ...
# 1               9/28/2004  ...
# 2               5/23/2006  ...
# 3              10/10/2000  ...
# 4                9/6/2006  ...
# ...                   ...  ...
# 29647       May 28th 2011  ...
# 29648     August 5th 2011  ...
# 29649     March 18th 2011  ...
# 29650  September 1st 2011  ...
# 29651        May 8th 2011  ...
#
#                                                     RAKE College  \
# 0      {old katniss, without really, shining capitol,...      {}
# 1      {unbearable sacrifice, silent corridor, haunti...      {}
# 2      {18 million, young alabama, winning film, slee...      {}
# 3      {romantic clash, regency england, radiant wit,...      {}
# 4      {deeply seductive, part might, love story, ext...      {}
# ...                                                  ...     ...
# 29647  {danielle break, sink deeper, unintentionally ...      {}
# 29648  {something happened, town claim, everyone want...      {}
# 29649  {ordinary life, old kara, guardian angel, -- r...      {}
# 29650  {original wayward, strange relic, notorious bi...      {}
# 29651  {village, test, ranks turns, last page, ketura...      {}
#
#       Relationships Divorce Death Wedding Stress Moving Coming of age Adulting
# 0                {}      {}    {}      {}     {}     {}            {}       {}
# 1                {}      {}    {}      {}     {}     {}            {}       {}
# 2                {}      {}    {}      {}     {}     {}            {}       {}
# 3                {}      {}    {}      {}     {}     {}            {}       {}
# 4                {}      {}    {}      {}     {}     {}            {}       {}
# ...             ...     ...   ...     ...    ...    ...           ...      ...
# 29647            {}      {}    {}      {}     {}     {}            {}       {}
# 29648            {}      {}    {}      {}     {}     {}            {}       {}
# 29649            {}      {}    {}      {}     {}     {}            {}       {}
# 29650            {}      {}    {}      {}     {}     {}            {}       {}
# 29651            {}      {}    {}      {}     {}     {}            {}       {}
#
# [29652 rows x 31 columns]
